# %%
import pandas as pd
import matplotlib.pyplot as plt
import urllib.request
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Okt
import konlpy
okt = Okt()
# Out:
# [0.029s][warning][os,thread] Attempt to protect stack guard pages failed (0x00000001694d0000-0x00000001694dc000).
# [0.029s][warning][os,thread] Attempt to deallocate stack guard pages failed.

# %%
import pandas as pd

c = pd.read_csv('/Users/ijunhui/Downloads/ubion/해커톤/kakao_2206.csv')

c['제목+본문'] = c['제목'] + c['본문']
c
# Out:
#                   전체날짜  종목명                        제목  \
# 0     2022.06.01 05:23  카카오  이시간에 카카오메인이 조선이 싹쓸이하네...
# 1     2022.06.01 08:44  카카오                돈은 많이 받으면서
# 2     2022.06.01 08:59  카카오      유영두 할아버지 넘 실망이에요~~^^
# 3     2022.06.01 09:29  카카오            빡빡이 하는짓 보면 모르나
# 4     2022.06.01 09:37  카카오     한오백년 전쟁하자는 미필 양키괴뢰!!!
# ...                ...  ...                       ...
# 6615  2022.06.30 23:31  카카오       이거보고 윤석열이 왕따라고 생각하면
# 6616  2022.06.30 23:34  카카오                    잠이 안온다
# 6617  2022.06.30 23:40  카카오           이거 액분전에 평균얼마엿어요
# 6618  2022.06.30 23:52  카카오                    나스닥 7천
# 6619  2022.06.30 23:54  카카오                   카카오 계열사
#
#                                                      본문  \
# 0     메인 7개 뉴스중에 5개가 조선1개가 동아 1개가 듣보잡 인터넷언론....이러니 주...
# 1     근무시간에 오디오라인 열어놓는게 불만이라니\n그냥 집에서 누워서 tv보면서 근무하고...
# 2     토른방에 남겨진 유영두 할아버지에 대한 댓글 입니다.\n"범수 똘마니 의심 "\n"...
# 3     김범수가 일궈낸 자리 편하게 앉아서 메타버스 빌미로 날로 먹을려고 하는거지\n\n카...
# 4     우리는 원래 하나였으나, 미,소에 의해 강제로 분단 당했습니다.\n피눈물도 없다는 ...
# ...                                                 ...
# 6615  https://youtu.be/C2-HTUyE6Y4\n\n당신은 천재ㅋㅋㅋ 왕따 아...
# 6616                               내일 인버스에 얼마나 꽂힐지..돈복사
# 6617                                              궁금합니다
# 6618                           간다.\n\n카카오는 3만 간다.\n\nㅋㅋ
# 6619                     이 쉐리들은 왜 배당을 안줌? 생각할수록 아주 괘씸하네
#
#                                                   제목+본문
# 0     이시간에 카카오메인이 조선이 싹쓸이하네...메인 7개 뉴스중에 5개가 조선1개가 동...
# 1     돈은 많이 받으면서근무시간에 오디오라인 열어놓는게 불만이라니\n그냥 집에서 누워서 ...
# 2     유영두 할아버지 넘 실망이에요~~^^토른방에 남겨진 유영두 할아버지에 대한 댓글 입...
# 3     빡빡이 하는짓 보면 모르나김범수가 일궈낸 자리 편하게 앉아서 메타버스 빌미로 날로 ...
# 4     한오백년 전쟁하자는 미필 양키괴뢰!!!우리는 원래 하나였으나, 미,소에 의해 강제로...
# ...                                                 ...
# 6615  이거보고 윤석열이 왕따라고 생각하면https://youtu.be/C2-HTUyE6Y...
# 6616                         잠이 안온다내일 인버스에 얼마나 꽂힐지..돈복사
# 6617                               이거 액분전에 평균얼마엿어요궁금합니다
# 6618                     나스닥 7천간다.\n\n카카오는 3만 간다.\n\nㅋㅋ
# 6619              카카오 계열사이 쉐리들은 왜 배당을 안줌? 생각할수록 아주 괘씸하네
#
# [6620 rows x 5 columns]

# %%
print(len(c['제목+본문'])) # 리뷰 개수 출력
# Out:
# 6620

# %%
print(c['제목+본문'].isnull().values.any())
# Out:
# False

# %%
train_data = c['제목+본문'].dropna(how = 'any') # Null 값이 존재하는 행 제거
print(train_data.isnull().values.any()) # Null 값이 존재하는지 확인
train_data
# Out:
# False
# 0       이시간에 카카오메인이 조선이 싹쓸이하네...메인 7개 뉴스중에 5개가 조선1개가 동...
# 1       돈은 많이 받으면서근무시간에 오디오라인 열어놓는게 불만이라니\n그냥 집에서 누워서 ...
# 2       유영두 할아버지 넘 실망이에요~~^^토른방에 남겨진 유영두 할아버지에 대한 댓글 입...
# 3       빡빡이 하는짓 보면 모르나김범수가 일궈낸 자리 편하게 앉아서 메타버스 빌미로 날로 ...
# 4       한오백년 전쟁하자는 미필 양키괴뢰!!!우리는 원래 하나였으나, 미,소에 의해 강제로...
#                               ...
# 6615    이거보고 윤석열이 왕따라고 생각하면https://youtu.be/C2-HTUyE6Y...
# 6616                           잠이 안온다내일 인버스에 얼마나 꽂힐지..돈복사
# 6617                                 이거 액분전에 평균얼마엿어요궁금합니다
# 6618                       나스닥 7천간다.\n\n카카오는 3만 간다.\n\nㅋㅋ
# 6619                카카오 계열사이 쉐리들은 왜 배당을 안줌? 생각할수록 아주 괘씸하네
# Name: 제목+본문, Length: 6620, dtype: object

# %%
train_data = train_data.astype(str)

train_data
# Out:
# 0       이시간에 카카오메인이 조선이 싹쓸이하네...메인 7개 뉴스중에 5개가 조선1개가 동...
# 1       돈은 많이 받으면서근무시간에 오디오라인 열어놓는게 불만이라니\n그냥 집에서 누워서 ...
# 2       유영두 할아버지 넘 실망이에요~~^^토른방에 남겨진 유영두 할아버지에 대한 댓글 입...
# 3       빡빡이 하는짓 보면 모르나김범수가 일궈낸 자리 편하게 앉아서 메타버스 빌미로 날로 ...
# 4       한오백년 전쟁하자는 미필 양키괴뢰!!!우리는 원래 하나였으나, 미,소에 의해 강제로...
#                               ...
# 6615    이거보고 윤석열이 왕따라고 생각하면https://youtu.be/C2-HTUyE6Y...
# 6616                           잠이 안온다내일 인버스에 얼마나 꽂힐지..돈복사
# 6617                                 이거 액분전에 평균얼마엿어요궁금합니다
# 6618                       나스닥 7천간다.\n\n카카오는 3만 간다.\n\nㅋㅋ
# 6619                카카오 계열사이 쉐리들은 왜 배당을 안줌? 생각할수록 아주 괘씸하네
# Name: 제목+본문, Length: 6620, dtype: object

# %%
train_data = train_data.str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# Out:
# /var/folders/wy/08qctpkd68s3_qyk81fm3w180000gn/T/ipykernel_9348/1668337309.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data = train_data.str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")

# %%
train_data[:5] # 상위 5개 출력
# Out:
# 0    이시간에 카카오메인이 조선이 싹쓸이하네메인 개 뉴스중에 개가 조선개가 동아 개가 듣...
# 1    돈은 많이 받으면서근무시간에 오디오라인 열어놓는게 불만이라니그냥 집에서 누워서 보면...
# 2    유영두 할아버지 넘 실망이에요토른방에 남겨진 유영두 할아버지에 대한 댓글 입니다범수...
# 3    빡빡이 하는짓 보면 모르나김범수가 일궈낸 자리 편하게 앉아서 메타버스 빌미로 날로 ...
# 4    한오백년 전쟁하자는 미필 양키괴뢰우리는 원래 하나였으나 미소에 의해 강제로 분단 당...
# Name: 제목+본문, dtype: object

# %%
# 불용어 정의
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# 형태소 분석기 OKT를 사용한 토큰화 작업 (다소 시간 소요)
okt = Okt()

tokenized_data = []
for sentence in (train_data):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    
    t_s = []
    for i in range(len(tokenized_sentence)):
        if len(tokenized_sentence[i]) > 1:
            t_s.append(tokenized_sentence[i])
        
    stopwords_removed_sentence = [word for word in t_s if not word in stopwords] # 불용어 제거
    tokenized_data.append(stopwords_removed_sentence)

# %%
tokenized_data
# Out:
# [['시간',
#   '카카오',
#   '메인',
#   '조선',
#   '쓸다',
#   '메인',
#   '뉴스',
#   '조선',
#   '동아',
#   '듣보잡',
#   '인터넷',
#   '언론',
#   '이러니',
#   '주가',
#   '모양',
#   '이지'],
#  ['많이',
#   '받다',
#   '근무시간',
#   '오디오',
#   '라인',
#   '열다',
#   '불만',
#   '이라니',
#   '그냥',
#   '에서',
#   '눕다',
#   '보다',
#   '근무',
#   '하고',
#   '싶다',
#   '그냥',
#   '출근',
#   '시키다',
#   '주가',
#   '반토막',
#   '나다',
#   '성과급',
#   '이랑',
#   '월급',
#   '인상',
#   '꼬박꼬박',
#   '받다',
#   '불만',
#   '졸라',
#   '많다'],
#  ['유영',
#   '할아버지',
#   '넘다',
#   '실망',
#   '이에요',
#   '토른방',
#   '남겨지다',
#   '유영',
#   '할아버지',
#   '대한',
#   '댓글',
#   '이다',
#   '범수',
#   '똘마',
#   '의심',
#   '생기다',
#   '사기꾼',
#   '방송',
#   '보다',
#   '사기꾼',
#   '인지',
#   '모르다',
#   '주식',
#   '접다',
#   '이렇다',
#   '댓글',
#   '보다',
#   '할아버지',
#   '너무',
#   '실망',
#   '크다',
#   '할아버지',
#   '이렇다',
#   '댓글',
#   '증말',
#   '사실',
#   '아니다',
#   '할아버지',
#   '믿다'],
#  ['빡빡이',
#   '보다',
#   '모르다',
#   '김범수',
#   '일구다',
#   '내다',
#   '자리',
#   '편하다',
#   '앉다',
#   '메타',
#   '버스',
#   '빌다',
#   '미로',
#   '날로',
#   '먹다',
#   '카카오',
#   '대표',
#   '빡빡이',
#   '바뀌다',
#   '직원',
#   '불리다',
#   '개선',
#   '되다'],
#  ['백년',
#   '전쟁',
#   '미필',
#   '양키',
#   '괴뢰',
#   '우리',
#   '원래',
#   '하나',
#   '이다',
#   '미소',
#   '의하다',
#   '강제',
#   '분단',
#   '당하다',
#   '눈물',
#   '없다',
#   '유태계',
#   '양키',
#   '군산',
#   '복합',
#   '체놈',
#   '천문학',
#   '재고',
#   '무기',
#   '진용',
#   '핏줄',
#   '학살',
#   '비운',
#   '슬프다',
#   '민족',
#   '이다',
#   '양키',
#   '점령',
#   '치하',
#   '지구',
#   '유일하다',
#   '전작권',
#   '없다',
#   '양키',
#   '괴뢰',
#   '형태',
#   '국군',
#   '북한',
#   '국내법',
#   '불법',
#   '단체',
#   '범법',
#   '통일',
#   '대상',
#   '이지',
#   '주적',
#   '아니다',
#   '이다',
#   '그런데',
#   '미필',
#   '윤석열',
#   '정권',
#   '에서',
#   '북한',
#   '주적',
#   '이라니',
#   '양키',
#   '사냥개',
#   '확실하다',
#   '밉다',
#   '국무장관',
#   '틸러슨',
#   '직언',
#   '일본',
#   '동맹',
#   '한국',
#   '파트너',
#   '직시',
#   '달리다',
#   '밉다',
#   '외교',
#   '동맹',
#   '친구',
#   '파트너',
#   '에서',
#   '한국',
#   '친구',
#   '아니다',
#   '파트너',
#   '앞잡이',
#   '그런데',
#   '동맹',
#   '타령',
#   '하루',
#   '이상',
#   '주둔',
#   '비등',
#   '강탈',
#   '당하다',
#   '치욕',
#   '충성'],
#  ['전라도', '아직', '식인', '문화', '풍습', '있다', '여행', '가보다', '안전하다', '지역', '동네', '알다'],
#  ['지주회사', '반등', '땅값', '상승', '가즈'],
#  ['맞이',
#   '카카오',
#   '로써',
#   '오랜',
#   '시간',
#   '겪다',
#   '하락',
#   '이제',
#   '단기',
#   '크다',
#   '앞두다',
#   '이평',
#   '조절',
#   '있다',
#   '지리하다',
#   '조정',
#   '받다',
#   '이제',
#   '단기',
#   '마무리',
#   '짓다',
#   '상승',
#   '곡선',
#   '그리고',
#   '있다',
#   '닷컴',
#   '이라는',
#   '목표',
#   '가지',
#   '진군',
#   '달이',
#   '되다',
#   '오랜',
#   '시간',
#   '걸리다',
#   '디지털',
#   '시간',
#   '세상',
#   '받아들이다',
#   '업보',
#   '이다',
#   '허니',
#   '급하다',
#   '않다',
#   '닷컴',
#   '까지',
#   '뚜벅뚜벅',
#   '걸어가다',
#   '가능하다',
#   '보다',
#   '삼전',
#   '가면',
#   '되다',
#   '홧팅',
#   '한번',
#   '올리다'],
#  ['버스', '토큰', '라는', '단어', '없다', '늘다', '누가', '나가다', '잘알다', '단어', '이다'],
#  ['대표', '최저', '시급', '받다', '인증', '궁금하다', '그런데', '이다', '슈카', '평단', '얼마', '물리다'],
#  ['고교생',
#   '투표',
#   '폐지',
#   '특정',
#   '정치',
#   '세력',
#   '학교',
#   '정치',
#   '장화',
#   '하고',
#   '학생',
#   '정치',
#   '도구',
#   '화하다',
#   '투표',
#   '다시',
#   '재고',
#   '교육기본법',
#   '에는',
#   '교육',
#   '정치',
#   '파당',
#   '또는',
#   '개인',
#   '편견',
#   '전파',
#   '방편',
#   '이용',
#   '되어다',
#   '아니다',
#   '되다',
#   '제조',
#   '교원',
#   '특정하다',
#   '정당',
#   '이나',
#   '정파',
#   '지지다',
#   '반대',
#   '학생',
#   '지도',
#   '거나',
#   '선동',
#   '서다',
#   '아니다',
#   '되다',
#   '제조',
#   '항고',
#   '적다',
#   '돼다',
#   '있다',
#   '보수',
#   '진보',
#   '라는',
#   '이념',
#   '대립',
#   '학교',
#   '오염시키다',
#   '정치권',
#   '이념',
#   '세력',
#   '까지',
#   '고등학교',
#   '들어오다',
#   '안되다',
#   '특히',
#   '만세',
#   '부터',
#   '성인',
#   '명시',
#   '만세',
#   '까지는',
#   '단독',
#   '법률상',
#   '유효',
#   '행위',
#   '없다',
#   '민법',
#   '충돌',
#   '민법',
#   '근거',
#   '만세',
#   '미만',
#   '청소년',
#   '규정',
#   '하고',
#   '담배',
#   '유해',
#   '약물',
#   '물론',
#   '유해',
#   '업다',
#   '유해',
#   '매체',
#   '로부터',
#   '보호',
#   '청소년',
#   '보호',
#   '과도',
#   '정면',
#   '배치',
#   '되다',
#   '이처럼',
#   '성년',
#   '연령',
#   '조정',
#   '따르다',
#   '부작용',
#   '혼란',
#   '해소',
#   '법령',
#   '정비',
#   '대해',
#   '다시',
#   '논의',
#   '하고',
#   '대책',
#   '마련',
#   '필요하다',
#   '그리고',
#   '전교조',
#   '장악',
#   '학교',
#   '보수',
#   '어디',
#   '있다',
#   '학생',
#   '대부분',
#   '좌편향',
#   '만들다',
#   '학생',
#   '어디',
#   '갈다',
#   '자명하다',
#   '일이',
#   '학생',
#   '정치화',
#   '시키다',
#   '촉법소년',
#   '이나',
#   '나오다',
#   '인성',
#   '교육',
#   '이나',
#   '똑바로',
#   '시키다',
#   '수업',
#   '시간',
#   '잠자다',
#   '깨우다',
#   '학생',
#   '선생',
#   '찌르다',
#   '오늘날',
#   '대한민국',
#   '교육',
#   '현실',
#   '이다',
#   '교사',
#   '깨우다',
#   '꾸짖다',
#   '밖에',
#   '나가다',
#   '훔치다',
#   '찌르다',
#   '고교생',
#   '구속',
#   '관련',
#   '기사',
#   '좌파',
#   '교육감',
#   '전교조',
#   '작품',
#   '아니다',
#   '미성년',
#   '다만세',
#   '선거권',
#   '재고'],
#  ['요즘',
#   '고교생',
#   '청소년',
#   '이냐',
#   '초등학생',
#   '말다',
#   '담배',
#   '피다',
#   '새삼',
#   '스럽게',
#   '그냥',
#   '투표',
#   '해주다',
#   '청소년',
#   '보호',
#   '없애다',
#   '베스트',
#   '아니다',
#   '년대',
#   '처럼',
#   '교생',
#   '주먹',
#   '갈다',
#   '날리다',
#   '빠따',
#   '체벌',
#   '허용',
#   '해주다'],
#  ['이대', '로만', '가다', '가다', '가다'],
#  ['뒤통수', '조심', '허다'],
#  ['년차', '오늘', '내일', '뛰다', '보다'],
#  ['성공', '실패'],
#  ['메타', '버스', '근무', '메타', '버스', '무제'],
#  ['껍데기',
#   '남다',
#   '회사',
#   '되다',
#   '부문',
#   '모조리',
#   '분할',
#   '자회사',
#   '떼다',
#   '카카오',
#   '남다',
#   '있다',
#   '사려',
#   '따로',
#   '상장',
#   '시키다',
#   '자회사',
#   '사다',
#   '구글',
#   '유튜브',
#   '구글',
#   '검색',
#   '구글',
#   '광고',
#   '이렇다',
#   '분하다',
#   '버리다',
#   '구글',
#   '주식',
#   '보다',
#   '있다',
#   '구글',
#   '카카오',
#   '그렇게',
#   '있다'],
#  ['유영', '만원', '간다', '이제', '만원', '받다', '카카오', '제일', '말다', '벌다', '배부르다'],
#  ['반토막', '작년', '최고', '찍다', '반토막', '이네'],
#  ['외국',
#   '인들',
#   '만천원',
#   '만들다',
#   '버리다',
#   '천원',
#   '까지',
#   '급상승',
#   '예상',
#   '월월',
#   '상승',
#   '강력',
#   '매수',
#   '개인',
#   '분석',
#   '알다',
#   '드리다',
#   '투자',
#   '에는',
#   '책임',
#   '지지',
#   '않다'],
#  ['지선',
#   '긴급',
#   '속보',
#   '더불다',
#   '위선',
#   '자당',
#   '더불다',
#   '만지다',
#   '더불다',
#   '조국',
#   '지방선거',
#   '참패',
#   '추카',
#   '추카',
#   '대장동',
#   '백현동',
#   '성남',
#   '들다',
#   '분당',
#   '무섭다',
#   '계양',
#   '튀다',
#   'ㅎㅋ',
#   '위선',
#   '정권',
#   '끝나다',
#   '년안',
#   '돌파'],
#  ['수익', '추다', '배달', '숟가락', '저서', '진짜', '마약', '대가리'],
#  ['영기',
#   '자다',
#   '그렇다',
#   '멀리',
#   '안나',
#   '카톡',
#   '규제',
#   '소리',
#   '바람',
#   '지금',
#   '본전',
#   '되다',
#   '천이',
#   '이제',
#   '다시다',
#   '볼일',
#   '카톡',
#   '쓰다',
#   '마르다',
#   '어제',
#   '계속',
#   '지우다',
#   '넘다',
#   '더불다',
#   '인거',
#   '안다',
#   '반성'],
#  ['사라지다',
#   '기업',
#   '갑질',
#   '네버',
#   '만도',
#   '중소',
#   '사다',
#   '가져오다',
#   '정도',
#   '만들다',
#   '끝나다',
#   '회사',
#   '상장',
#   '종이',
#   '장사',
#   '상부',
#   '이니'],
#  ['쌀값',
#   '수확',
#   '기이',
#   '풍부하다',
#   '불구',
#   '하고',
#   '지난',
#   '주간',
#   '오르다',
#   '다다르다',
#   '주방',
#   '시장',
#   '에서',
#   '거치다',
#   '가격',
#   '오르다',
#   '고급',
#   '어제',
#   '에서',
#   '판매',
#   '되어다',
#   '모든',
#   '최신',
#   '뉴스',
#   '보다',
#   '뉴스',
#   '채널',
#   '팔로우',
#   '방글라데시',
#   '무역',
#   '공사',
#   '따르다',
#   '잡곡',
#   '곱다',
#   '가격',
#   '지난',
#   '동안',
#   '각각',
#   '오르다',
#   '상인',
#   '정미소',
#   '소유',
#   '주가',
#   '시장',
#   '충분하다',
#   '공급',
#   '않다',
#   '있다',
#   '공급',
#   '개선',
#   '않다',
#   '가격',
#   '오르다',
#   '있다',
#   '국장',
#   '질문',
#   '대해',
#   '농부',
#   '작년',
#   '보다',
#   '헥타르',
#   '많다',
#   '헥타르',
#   '에서',
#   '보로',
#   '경작',
#   '때문',
#   '시장',
#   '부족하다',
#   '않다',
#   '이번',
#   '시즌',
#   '헥타르',
#   '에서만',
#   '홍수',
#   '피해',
#   '입다',
#   '게다가',
#   '연출',
#   '좋다',
#   '이번',
#   '시즌',
#   '수확',
#   '예상',
#   '목표',
#   '거의',
#   '가다',
#   '이미',
#   '달성',
#   '되어다',
#   '덧붙이다',
#   '게다가',
#   '까지',
#   '전국',
#   '각지',
#   '에서',
#   '농부',
#   '계속',
#   '에서',
#   '가져오다',
#   '다그',
#   '시장',
#   '에서',
#   '인위',
#   '부족',
#   '초래',
#   '상인',
#   '제분업자',
#   '비난',
#   '그러나',
#   '다른',
#   '지역',
#   '여러',
#   '정미소',
#   '주인',
#   '농민',
#   '에게서',
#   '구입',
#   '제대로',
#   '익다',
#   '않다',
#   '즉시',
#   '생산',
#   '만큼',
#   '충분하다',
#   '건조',
#   '되다',
#   '않다',
#   '한편',
#   '정부',
#   '물가',
#   '통제',
#   '위해',
#   '전국',
#   '습격',
#   '첫날',
#   '부터',
#   '크다',
#   '효과',
#   '거두다',
#   '어제',
#   '오후',
#   '관리',
#   '다카',
#   '부바',
#   '자르다',
#   '도매시장',
#   '에서',
#   '드라이브',
#   '대부분',
#   '상점',
#   '닫다',
#   '나타나다',
#   '식약처',
#   '식약처',
#   '관계자',
#   '오늘',
#   '수도',
#   '에서',
#   '드라이브',
#   '예정',
#   '이다',
#   '운동',
#   '내각',
#   '관리',
#   '에게',
#   '승인',
#   '되다',
#   '않다',
#   '사업',
#   '비축',
#   '연루',
#   '되다',
#   '회사',
#   '대한',
#   '조치',
#   '취하',
#   '도록',
#   '지시',
#   '지다',
#   '하루',
#   '만에',
#   '시작',
#   '되어다',
#   '칸드',
#   '크다',
#   '이슬람',
#   '내무장관',
#   '일요일',
#   '법적',
#   '승인',
#   '없이',
#   '일부',
#   '대기업',
#   '사재기',
#   '하고',
#   '있다',
#   '어제',
#   '수도',
#   '파라',
#   '주민',
#   '수도',
#   '주방',
#   '에서',
#   '밉다',
#   '사다',
#   '다른',
#   '생필품',
#   '가격',
#   '오르다',
#   '바꾸다',
#   '이다',
#   '이제',
#   '늘다',
#   '이다',
#   '다그',
#   '지출',
#   '줄이다',
#   '위해',
#   '정말',
#   '열심히',
#   '노력',
#   '하고',
#   '있다',
#   '실패하다',
#   '있다',
#   '다비',
#   '난하다',
#   '국내',
#   '최대',
#   '규모',
#   '시장',
#   '하나',
#   '시장',
#   '에서',
#   '우리',
#   '특파원',
#   '어제',
#   '자루',
#   '판매',
#   '되어다',
#   '발견',
#   '상인',
#   '자루',
#   '가격',
#   '동안',
#   '인상',
#   '되어다',
#   '시장',
#   '가게',
#   '주인',
#   '골다',
#   '라바',
#   '가격',
#   '거의',
#   '매일',
#   '바뀌다',
#   '있다',
#   '대해',
#   '정미소',
#   '주인',
#   '비난',
#   '반면',
#   '공동',
#   '비서',
#   '늘다',
#   '방앗간',
#   '소유',
#   '주가',
#   '높다',
#   '가격',
#   '구매',
#   '하고',
#   '있다',
#   '주장',
#   '가격',
#   '토요일',
#   '인상',
#   '되어다',
#   '전무',
#   '사인',
#   '따르다',
#   '가격',
#   '비난',
#   '그러나',
#   '농부',
#   '동의',
#   '않다',
#   '재배',
#   '가격',
#   '오르다',
#   '않다',
#   '에서',
#   '상인',
#   '공급',
#   '부족',
#   '비난',
#   '우박',
#   '폭풍',
#   '해충',
#   '공격',
#   '수확량',
#   '크게',
#   '감소',
#   '시키다',
#   '재고',
#   '도매업자',
#   '협회',
#   '회장',
#   '늘다',
#   '지역',
#   '생산량',
#   '헥타르',
#   '예상',
#   '보다',
#   '적다',
#   '제분업자',
#   '생산',
#   '하고',
#   '공급',
#   '있다',
#   '때문',
#   '이번',
#   '가격',
#   '하락',
#   '기대하다',
#   '기자',
#   '보고서',
#   '기여',
#   '요약',
#   '인도',
#   '식량',
#   '자원',
#   '무기',
#   '관련',
#   '홀딩스'],
#  ['카카오',
#   '너무',
#   '씹다',
#   '거품',
#   '이라고',
#   '네이버',
#   '사라',
#   'ㅋㅋㅋ',
#   '네이버',
#   '두다',
#   '사다',
#   'ㅋㅋㅋㅋ'],
#  ['카카오', '주가', '전망', '분석', '객관', '분석', '감정이입', '말다'],
#  ['오늘',
#   '압축',
#   '영화',
#   '재미',
#   '이번',
#   '선거',
#   '이재명',
#   '죽이다',
#   '경기도',
#   '이재명',
#   '흔적',
#   '완전하다',
#   '없애다',
#   '국힘',
#   '작전',
#   '이다',
#   '윤석열',
#   '뒤통수',
#   '정신',
#   '번쩍',
#   '들다',
#   '다다르다',
#   '지선',
#   '결과',
#   '필요',
#   '없다',
#   '이재명',
#   '김동연',
#   '승리',
#   '이번',
#   '선거',
#   '영화',
#   '하일',
#   '라이트',
#   '재미',
#   '있다',
#   '영화',
#   '보다'],
#  ['성탄절',
#   '토요일',
#   '일요',
#   '일일',
#   '경우',
#   '월요일',
#   '대체공휴일',
#   '지정',
#   '해주다',
#   '성탄절',
#   '토요일',
#   '일요',
#   '일일',
#   '경우',
#   '월요일',
#   '대체공휴일',
#   '지정',
#   '해주다'],
#  ['두번째', '물어보다', '평단', '만원', '마르다'],
#  ['두번째',
#   '물어보다',
#   '평단',
#   '만원',
#   '마르다',
#   '처지',
#   '비슷하다',
#   '보다',
#   '낮다',
#   '금방',
#   '오다',
#   '겁니다',
#   '내다',
#   '기다리다',
#   '손절',
#   '말다'],
#  ['쌀값',
#   '수확',
#   '기이',
#   '풍부하다',
#   '불구',
#   '하고',
#   '지난',
#   '주간',
#   '오르다',
#   '다다르다',
#   '주방',
#   '시장',
#   '에서',
#   '거치다',
#   '가격',
#   '오르다',
#   '고급',
#   '어제',
#   '에서',
#   '판매',
#   '되어다',
#   '모든',
#   '최신',
#   '뉴스',
#   '보다',
#   '뉴스',
#   '채널',
#   '팔로우',
#   '방글라데시',
#   '무역',
#   '공사',
#   '따르다',
#   '잡곡',
#   '곱다',
#   '가격',
#   '지난',
#   '동안',
#   '각각',
#   '오르다',
#   '상인',
#   '정미소',
#   '소유',
#   '주가',
#   '시장',
#   '충분하다',
#   '공급',
#   '않다',
#   '있다',
#   '공급',
#   '개선',
#   '않다',
#   '가격',
#   '오르다',
#   '있다',
#   '국장',
#   '질문',
#   '대해',
#   '농부',
#   '작년',
#   '보다',
#   '헥타르',
#   '많다',
#   '헥타르',
#   '에서',
#   '보로',
#   '경작',
#   '때문',
#   '시장',
#   '부족하다',
#   '않다',
#   '이번',
#   '시즌',
#   '헥타르',
#   '에서만',
#   '홍수',
#   '피해',
#   '입다',
#   '게다가',
#   '연출',
#   '좋다',
#   '이번',
#   '시즌',
#   '수확',
#   '예상',
#   '목표',
#   '거의',
#   '가다',
#   '이미',
#   '달성',
#   '되어다',
#   '덧붙이다',
#   '게다가',
#   '까지',
#   '전국',
#   '각지',
#   '에서',
#   '농부',
#   '계속',
#   '에서',
#   '가져오다',
#   '다그',
#   '시장',
#   '에서',
#   '인위',
#   '부족',
#   '초래',
#   '상인',
#   '제분업자',
#   '비난',
#   '그러나',
#   '다른',
#   '지역',
#   '여러',
#   '정미소',
#   '주인',
#   '농민',
#   '에게서',
#   '구입',
#   '제대로',
#   '익다',
#   '않다',
#   '즉시',
#   '생산',
#   '만큼',
#   '충분하다',
#   '건조',
#   '되다',
#   '않다',
#   '한편',
#   '정부',
#   '물가',
#   '통제',
#   '위해',
#   '전국',
#   '습격',
#   '첫날',
#   '부터',
#   '크다',
#   '효과',
#   '거두다',
#   '어제',
#   '오후',
#   '관리',
#   '다카',
#   '부바',
#   '자르다',
#   '도매시장',
#   '에서',
#   '드라이브',
#   '대부분',
#   '상점',
#   '닫다',
#   '나타나다',
#   '식약처',
#   '식약처',
#   '관계자',
#   '오늘',
#   '수도',
#   '에서',
#   '드라이브',
#   '예정',
#   '이다',
#   '운동',
#   '내각',
#   '관리',
#   '에게',
#   '승인',
#   '되다',
#   '않다',
#   '사업',
#   '비축',
#   '연루',
#   '되다',
#   '회사',
#   '대한',
#   '조치',
#   '취하',
#   '도록',
#   '지시',
#   '지다',
#   '하루',
#   '만에',
#   '시작',
#   '되어다',
#   '칸드',
#   '크다',
#   '이슬람',
#   '내무장관',
#   '일요일',
#   '법적',
#   '승인',
#   '없이',
#   '일부',
#   '대기업',
#   '사재기',
#   '하고',
#   '있다',
#   '어제',
#   '수도',
#   '파라',
#   '주민',
#   '수도',
#   '주방',
#   '에서',
#   '밉다',
#   '사다',
#   '다른',
#   '생필품',
#   '가격',
#   '오르다',
#   '바꾸다',
#   '이다',
#   '이제',
#   '늘다',
#   '이다',
#   '다그',
#   '지출',
#   '줄이다',
#   '위해',
#   '정말',
#   '열심히',
#   '노력',
#   '하고',
#   '있다',
#   '실패하다',
#   '있다',
#   '다비',
#   '난하다',
#   '국내',
#   '최대',
#   '규모',
#   '시장',
#   '하나',
#   '시장',
#   '에서',
#   '우리',
#   '특파원',
#   '어제',
#   '자루',
#   '판매',
#   '되어다',
#   '발견',
#   '상인',
#   '자루',
#   '가격',
#   '동안',
#   '인상',
#   '되어다',
#   '시장',
#   '가게',
#   '주인',
#   '골다',
#   '라바',
#   '가격',
#   '거의',
#   '매일',
#   '바뀌다',
#   '있다',
#   '대해',
#   '정미소',
#   '주인',
#   '비난',
#   '반면',
#   '공동',
#   '비서',
#   '늘다',
#   '방앗간',
#   '소유',
#   '주가',
#   '높다',
#   '가격',
#   '구매',
#   '하고',
#   '있다',
#   '주장',
#   '가격',
#   '토요일',
#   '인상',
#   '되어다',
#   '전무',
#   '사인',
#   '따르다',
#   '가격',
#   '비난',
#   '그러나',
#   '농부',
#   '동의',
#   '않다',
#   '재배',
#   '가격',
#   '오르다',
#   '않다',
#   '에서',
#   '상인',
#   '공급',
#   '부족',
#   '비난',
#   '우박',
#   '폭풍',
#   '해충',
#   '공격',
#   '수확량',
#   '크게',
#   '감소',
#   '시키다',
#   '재고',
#   '도매업자',
#   '협회',
#   '회장',
#   '늘다',
#   '지역',
#   '생산량',
#   '헥타르',
#   '예상',
#   '보다',
#   '적다',
#   '제분업자',
#   '생산',
#   '하고',
#   '공급',
#   '있다',
#   '때문',
#   '이번',
#   '가격',
#   '하락',
#   '기대하다',
#   '기자',
#   '보고서',
#   '기여',
#   '요약',
#   '인도',
#   '식량',
#   '자원',
#   '무기',
#   '관련',
#   '홀딩스'],
#  ['호재', '공시', '매수', '세력', '유입'],
#  ['올려놓다', '오늘', '허다', '빼다', 'ㅋㅋㅋ'],
#  ['입성', '카카오', '화이팅'],
#  ['탈출', 'ㅇㅇ'],
#  ['은근', '만원', '자다', '버티다', '요원', '짜다', '주제'],
#  ['앵두', '부터', '오르다', '지만', '오르다', 'ㅋㅋ', '또낙엿쥬'],
#  ['기술',
#   '폭락',
#   '와도',
#   '걱정',
#   '없다',
#   '카카오',
#   '기술',
#   '무슨',
#   '기술',
#   '동네',
#   '상권',
#   '뺏다',
#   '기술',
#   '대리',
#   '기사',
#   '택시',
#   '시장',
#   '숟가락',
#   '얹다',
#   '모자라다',
#   '탁송',
#   '대리',
#   '시장',
#   '발짝',
#   '걸치다',
#   '기술',
#   '무슨',
#   '기술',
#   '주임',
#   'ㅋㅋ',
#   '주님',
#   '우리',
#   '기술',
#   '폭락',
#   '걱정',
#   '되다',
#   '편안하다'],
#  ['ㅇㅇㅊ', '기업', '교본', '이네', '상도', '없다', '기술', '아무', '거도', '없다', 'ㅉㅉ'],
#  ['지금', '이니', 'ㅇㅇ'],
#  ['폭락',
#   '무슨',
#   '네이버',
#   '하수',
#   '같다',
#   '존재',
#   '항상',
#   '네이버',
#   '보다',
#   '많이',
#   '떨어지다',
#   '항상',
#   '네이버',
#   '보다',
#   '조금',
#   '오르다',
#   '나은',
#   '하나',
#   '없다',
#   '평생',
#   '네이버',
#   '빨다'],
#  ['오늘', '매수', '기회', '한번', 'ㅋㅋㅋ', '깜사'],
#  ['쑤뤠기', '같다', '같다', '종목'],
#  ['지금', '하락', '시키다', '전혀', '자연', '스럽지', '않다'],
#  ['팔카오', '에서', '언젠가', '진행'],
#  ['네이버', '가라', '떨구다', '일등', '오르다', '꼴등'],
#  ['너무',
#   '기초',
#   '체력',
#   '없다',
#   '나스닥',
#   '내리다',
#   '그냥',
#   '치다',
#   '발리',
#   'ㅋㅋ',
#   '분할',
#   '그만',
#   '치다',
#   '진짜'],
#  ['커버', '통정', '바닥'],
#  ['분할', '매수', '금액', '싸다', '빨리', '빨리', '매수'],
#  ['반등',
#   '제데로',
#   '지이미',
#   '하락',
#   '깊다',
#   '모두',
#   '털다',
#   '나가다',
#   '이미',
#   '물리다',
#   '용돈',
#   '벌리다',
#   '매하',
#   '안되다'],
#  ['게뭐', '괜찮다', '만원', '이라도', '수익', '이다', '제자리', '찾아가다'],
#  ['이건', '유튜브', '때문', '이다', 'ㅜㅜ'],
#  ['공매도', '맛집', '이네', '아주', '그냥', '주무르다'],
#  ['월일',
#   '카카오',
#   '음식',
#   '배송',
#   '시작',
#   'ㅅㅅ',
#   '오늘',
#   '카카오',
#   '음식',
#   '배송',
#   '출시일',
#   'ㅅㅅ',
#   '카카',
#   '오픽',
#   '크다',
#   '오픈',
#   '일이',
#   '네오',
#   '오후',
#   '불장난',
#   '인정'],
#  ['아이', '고이', '크다', '보다'],
#  ['카카오',
#   '직원',
#   '부르다',
#   '있다',
#   '사람',
#   '카카오',
#   '직원',
#   '부러워하다',
#   '불평',
#   '이라니',
#   '옛날',
#   '부터',
#   '자다',
#   '해주다',
#   '상전',
#   '모르다',
#   '보다',
#   '있다',
#   '직원',
#   '너무',
#   '우대',
#   '해주다',
#   '안되다',
#   '휘둘',
#   '리지',
#   '말고',
#   '잡다'],
#  ['한주', '내주다', '외인', '한테', '싼값', '넘기다', 'ㅋㅋ', '바닥', '에서', '털리다', '주식', '접다'],
#  ['도대체', '십만원', '넘다', '기다리다', '지치다'],
#  ['느낌', '오후', '올리다', 'ㅎㅎ'],
#  ['한주',
#   '내주다',
#   '주식',
#   '사다',
#   '까지',
#   '가지',
#   '간다',
#   '카카오',
#   '가지',
#   '있다',
#   '올라가다',
#   '까지',
#   '가지',
#   '있다'],
#  ['유영',
#   '만원',
#   '회비',
#   '내다',
#   '사람',
#   '끄다',
#   '요추',
#   '천하다',
#   '네이버',
#   '한전',
#   '카카오',
#   '바이오',
#   '파다',
#   '종목',
#   '오르다',
#   '반토막',
#   '나다',
#   '믿다',
#   '따르다',
#   '사람',
#   '신기하다'],
#  ['이르다', '뒤지다', '쓰다', '비뚤어지다', '되다', '이제', '벗다', '버리다'],
#  ['가다', 'ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['게다가', '사람', '까지', '모여들다', '왜곡', '되다', '이제', '그러하다', '사람', '벗다', '버리다'],
#  ['개미', '털다', '그만', '올라가다', '빨리', '빨리', '올리다', '올리다'],
#  ['시작', '되어다', '오늘', '전설', '날임'],
#  ['가즈'],
#  ['도리',
#   '당선',
#   '효과',
#   '끝나다',
#   'ㅋㅋ',
#   '확장',
#   '타령',
#   '따다',
#   '끝나다',
#   '카카오',
#   '대표',
#   '분할',
#   '기업',
#   '이라서',
#   '매력',
#   '없다',
#   '플랫폼',
#   '기업',
#   '확장',
#   '생명',
#   '이라',
#   '면서',
#   '빨다',
#   '구글',
#   '같다',
#   '세계',
#   '최고',
#   '플렛폼',
#   '기업',
#   '바보',
#   '라서',
#   '분할',
#   '확장',
#   '포기',
#   '기업',
#   '갈껀',
#   '경영',
#   '발판',
#   '마련',
#   '복잡하다',
#   '지배구조',
#   '통해',
#   '증여',
#   '미치다',
#   '기업',
#   '갈껀',
#   '정도',
#   '보고',
#   '장투'],
#  ['아직', '월급', '받다', '계시다', '이다'],
#  ['네이버', '따라가다', '고고싱'],
#  ['네이버',
#   '양봉',
#   '카카오',
#   '음봉',
#   '도주',
#   '아니다',
#   '유투브',
#   '에서',
#   '사라',
#   '고해',
#   '사면',
#   '대안',
#   '오르다',
#   '그리고',
#   '도주',
#   '천보',
#   '에프',
#   '에코',
#   '프로비',
#   '이다',
#   '가다',
#   '차트',
#   '보다',
#   '어휴',
#   '못버',
#   '이유',
#   '부안',
#   '하고',
#   '유트브',
#   '보고',
#   '사서'],
#  ['카카오', '되다'],
#  ['카카오', '화이팅', '오늘', '기울다', '상승세', '추가', '매입', '빨리', '빨리', '십만원'],
#  ['회생', '방법', '없다', '보다', '한계', '정이', '나오다', '건가', '거의', '쓰레기', '기업'],
#  ['ㅅㄲ',
#   '야공',
#   '그만',
#   '해좀',
#   '올라가다',
#   '쓰레기',
#   'ㅅㄲ',
#   '조금',
#   '오르다',
#   '싶다',
#   '매질',
#   '이야',
#   '망하다',
#   '유대',
#   '자본',
#   '정공',
#   '주식',
#   '하란',
#   '이야',
#   '버러지',
#   'ㅅㄲ'],
#  ['카카오',
#   '오주',
#   '사업',
#   '성장',
#   '유지',
#   '되다',
#   '가정',
#   '정당화',
#   '되다',
#   '있다',
#   '밸류',
#   '판단',
#   '투자',
#   '포인트',
#   '코마',
#   '모델',
#   '기반',
#   '글로벌',
#   '웹툰',
#   '시장',
#   '공략',
#   '가속',
#   '웹툰',
#   '아니다',
#   '게임',
#   '영역',
#   '에서도',
#   '성장',
#   '라고',
#   '분석'],
#  ['부터', '네이버', '사라', '니깐', '아직', '사다', '답답하다'],
#  ['네이버', '비교', '네이버', '카카오', '처럼', '여기저기', '상장', '시키다', '팔다', '창로', '보이'],
#  ['이상', '시끄럽다', '말고', '올라가다', '모두', '합치다', '올라가다', '영차', '영차', '올라가다'],
#  ['정신차려라',
#   '간다',
#   '만대',
#   '에서',
#   '장난',
#   '라야',
#   '되다',
#   '상황',
#   '빨리',
#   '올려놓다',
#   '채우다',
#   '생각',
#   '말고',
#   '주주',
#   '같이',
#   '배좀',
#   '불리',
#   '빨리',
#   '상한',
#   '날다'],
#  ['평단', '놀이', '시작', '내리다', '웃다'],
#  ['아하', '이제', '한숨', '나오다'],
#  ['공나베르', '대피'],
#  ['크다', '마지막', '발악', '문재인', '도주', '윤석열', '올려주다', 'ㅋㅋㅋ', '되다'],
#  ['반토막',
#   '카카오',
#   '언제',
#   '이나',
#   '오르다',
#   '진짜',
#   '범수',
#   '내내',
#   '치다',
#   '맞다',
#   '보고',
#   '있다',
#   '재밌다'],
#  ['증권', '목표', '높다', '이유지', '물리다', '탈출', '되다'],
#  ['세번', '물어보다', '평단', '만원', '마르다', '타다', '목마름', '달다', '탈출', '가능하다'],
#  ['아직도', '밀리', '사라', '부추기다', '슈퍼', '개미', '맞다', '그냥', '회원', '수로', '챙기다'],
#  ['만에',
#   '신규',
#   '상장',
#   '합계',
#   '최소',
#   '규모',
#   '예비',
#   '장사',
#   '기업',
#   '공개',
#   '위축',
#   '되다',
#   '시장',
#   '규모',
#   '신종',
#   '코로나바이러스',
#   '코로나',
#   '확산',
#   '이전',
#   '돌아가다',
#   '분위기',
#   '급기야',
#   '지난달',
#   '만에',
#   '최소',
#   '금액',
#   '기록',
#   '당초',
#   '예정',
#   '돼다',
#   '대다',
#   '들이다',
#   '상장',
#   '미루다',
#   '있다',
#   '분위기',
#   '반전',
#   '의치',
#   '않다',
#   '보이다',
#   '한국',
#   '거래소',
#   '따르다',
#   '지난',
#   '신규',
#   '상장',
#   '종목',
#   '공모',
#   '합계',
#   '억원',
#   '집계',
#   '돼다',
#   '이다',
#   '코로나',
#   '확산',
#   '초기',
#   '지난',
#   '억원',
#   '이후',
#   '최소',
#   '규모',
#   '신규',
#   '상장도',
#   '역시',
#   '만에',
#   '가장',
#   '적다',
#   '올해',
#   '시장',
#   '점진',
#   '하향',
#   '세다',
#   '연초',
#   '에너지',
#   '솔루션',
#   '상장',
#   '신호탄',
#   '미노',
#   '공모',
#   '흥행',
#   '기대',
#   '돼다',
#   '시장',
#   '개월',
#   '째다',
#   '위축',
#   '되다',
#   '있다',
#   '조억원',
#   '억원',
#   '들다',
#   '급감',
#   '억원',
#   '에는',
#   '여기',
#   '반토막',
#   '나다',
#   '억원',
#   '부터는',
#   '억원',
#   '에도',
#   '이르다',
#   '하고',
#   '있다',
#   '업계',
#   '올해',
#   '상반기',
#   '모시',
#   '장이',
#   '냉각기',
#   '접다',
#   '번째',
#   '원인',
#   '대다',
#   '들다',
#   '상장',
#   '철회',
#   '꼽았다',
#   '올해',
#   '들다',
#   '공모',
#   '주가',
#   '상장',
#   '철회',
#   '이중',
#   '단위',
#   '이나',
#   '돼다',
#   '지난달',
#   '쉴더스',
#   '스토어',
#   '코스피',
#   '입성',
#   '노리다',
#   '기관',
#   '수요',
#   '예측',
#   '경쟁률',
#   '기대',
#   '미치다',
#   '철회',
#   '엔지니어링',
#   '지난',
#   '같다',
#   '이유',
#   '상장',
#   '시도',
#   '거두다',
#   '금융투자',
#   '업계',
#   '관계자',
#   '대다',
#   '들이다',
#   '연달',
#   '수요',
#   '예측',
#   '과정',
#   '에서',
#   '발목',
#   '잡히다',
#   '있다',
#   '대해',
#   '최근',
#   '상장',
#   '이후',
#   '기업',
#   '주가',
#   '부진',
#   '이어지다',
#   '있다',
#   '과정',
#   '에서',
#   '수익',
#   '성장',
#   '더욱',
#   '보수',
#   '분석',
#   '기조',
#   '강하다',
#   '설명',
#   '실제',
#   '상장',
#   '당시',
#   '평가',
#   '논란',
#   '홍역',
#   '치르다',
#   '종목',
#   '상장',
#   '성장',
#   '기대',
#   '미치다',
#   '있다',
#   '관측',
#   '되다',
#   '유안',
#   '증권',
#   '따르다',
#   '상장',
#   '에너지',
#   '솔루션',
#   '카카오',
#   '뱅크',
#   '카카오',
#   '페이',
#   '크래프톤',
#   '올해',
#   '영업',
#   '이익',
#   '합계',
#   '망치',
#   '조억원',
#   '에서',
#   '조억',
#   '하향',
#   '조정',
#   '돼다',
#   '조창민',
#   '유안',
#   '증권',
#   '연구원',
#   '이미',
#   '망치',
#   '회한',
#   '상황',
#   '에서',
#   '대한',
#   '영업',
#   '망치',
#   '하향',
#   '조정',
#   '지속',
#   '되다',
#   '신규',
#   '상장',
#   '되다',
#   '기업',
#   '대해',
#   '투자자',
#   '느끼다',
#   '불확실',
#   '성은',
#   '더욱',
#   '확대',
#   '되다',
#   '이라고',
#   '진단',
#   '전문가',
#   '시장',
#   '투심',
#   '회복',
#   '나서다',
#   '기업',
#   '합리',
#   '몸값',
#   '설정',
#   '동반',
#   '돼다',
#   '지적',
#   '그러나',
#   '예비',
#   '모주',
#   '공모',
#   '책정',
#   '노력',
#   '보다',
#   '시장',
#   '여건',
#   '고려',
#   '미루다',
#   '있다',
#   '시장',
#   '침체',
#   '한동안',
#   '이어지다',
#   '전망',
#   '이다',
#   '스팩',
#   '제외',
#   '하고',
#   '종목',
#   '공모',
#   '진행',
#   '모두',
#   '코스닥',
#   '종목',
#   '코스피',
#   '종목',
#   '이다',
#   '쏘다',
#   '컬리',
#   '오아시스',
#   '케이',
#   '뱅크',
#   '상장',
#   '일정',
#   '연기',
#   '하반기',
#   '시장',
#   '에서도',
#   '대다',
#   '가뭄',
#   '예정',
#   '돼다',
#   '이석훈',
#   '자본시장',
#   '연구원',
#   '위원',
#   '적정',
#   '공모',
#   '가다',
#   '기업',
#   '투자자',
#   '모두',
#   '에게',
#   '중요하다',
#   '해외',
#   '사례',
#   '에서와',
#   '같이',
#   '주관',
#   '회사',
#   '공모',
#   '가르다',
#   '결정',
#   '개인',
#   '투자자',
#   '청약',
#   '되다',
#   '개인',
#   '투자자',
#   '수요',
#   '까지',
#   '포함',
#   '검토',
#   '있다',
#   '적정하다',
#   '공모',
#   '결정',
#   '크다',
#   '도움',
#   '이라고',
#   '올해',
#   '모주',
#   '수익',
#   '거품',
#   '이고',
#   '내년',
#   '에나',
#   '가능하다'],
#  ['좋다',
#   '세력',
#   '네이버',
#   '세력',
#   '좋다',
#   '이라도',
#   '잡고',
#   '따라가다',
#   '가다',
#   '틀다',
#   '들다',
#   '앉다',
#   '좋다',
#   '기미'],
#  ['네이버', '보합', '이다', '우리', '최소', '보합', '가다', '출발'],
#  ['네이버',
#   '낳다',
#   '이유',
#   '가지',
#   '인지도',
#   '낳다',
#   '매형',
#   '네이바',
#   '기술',
#   '낳다',
#   '보다',
#   '카카오',
#   '조치',
#   '네이바',
#   '낳다',
#   '그렇다',
#   '포털',
#   '무족',
#   '네이바',
#   '우리',
#   '가족',
#   '카카오',
#   '네이바',
#   '가족',
#   '싸우다',
#   '네이바',
#   '오다',
#   '가치',
#   '축배',
#   '들다',
#   '자가',
#   '네이바',
#   '네이바',
#   '사랑'],
#  ['원오', '사면', 'ㅋㅋ'],
#  ['치다',
#   '팼으',
#   '돼다',
#   '카카오',
#   '자회사',
#   '상장',
#   '이상',
#   '카카오',
#   '장사',
#   '사용',
#   '받다',
#   '카카오',
#   '주주',
#   '카카오',
#   '에게',
#   '수수료',
#   '제대로',
#   '그리고',
#   '범수',
#   '대표',
#   '주가',
#   '부양',
#   '전력',
#   '하라'],
#  ['재무제표',
#   '보다',
#   '모르다',
#   '흑우',
#   '큰일',
#   '이네',
#   '대비',
#   '네이버',
#   '빠지다',
#   'ㅉㅉ',
#   '네이버',
#   '카카오',
#   'ㅇㅋ'],
#  ['네이버', '화이팅'],
#  ['거의', '오다', '같다', '내일', '부터', '웨이', '가보다'],
#  ['네이버', '빨갛다', '같이', '가즈', '최소한'],
#  ['유영',
#   '할아버지',
#   '전상',
#   '서영',
#   '할아버지',
#   '작년',
#   '이후',
#   '당신',
#   '께서',
#   '카카오',
#   '대하',
#   '하나',
#   '라도',
#   '맞다',
#   '있다',
#   '무책임하다',
#   '없다',
#   '내용',
#   '수많다',
#   '개미',
#   '고통',
#   '주다',
#   '유트브',
#   '방송',
#   '계속',
#   '이유',
#   '무엇',
#   '인가요',
#   '희망고문',
#   '개미',
#   '눈물',
#   '흘리다',
#   '유트브',
#   '방송',
#   '자제',
#   '주시',
#   '감사하다'],
#  ['빨리',
#   '빨리',
#   '올라가다',
#   '종가',
#   '시간',
#   '밖에',
#   '남다',
#   '빨리',
#   '빨리',
#   '올라가다',
#   '빨리',
#   '올리다',
#   '올리다',
#   '올리다'],
#  ['카카오',
#   '대표',
#   '한테',
#   '건의',
#   '하나',
#   '포탈',
#   '이름',
#   '카카오',
#   '바꾸다',
#   '그러면',
#   '네이버',
#   '쓰다',
#   '카카오',
#   '쓸다'],
#  ['가다', '깨지다', '고작', '저걸', '넘어서다', 'ㅠㅠ'],
#  ['대형주',
#   '적정',
#   '주가',
#   '삼전',
#   '만원',
#   '만원',
#   '하이닉스',
#   '만원',
#   '현대차',
#   '만원',
#   '카카오',
#   '만원',
#   '삼성',
#   '만원',
#   '지화학',
#   '엘지',
#   '만원',
#   '셀트리온',
#   '삼성',
#   '바이오',
#   '직스',
#   '만원',
#   '신한지주',
#   '만원',
#   '하나',
#   '금융',
#   '지주',
#   '만원',
#   '금융',
#   '만원',
#   '한국전력',
#   '만원',
#   '만천원',
#   '텔레콤',
#   '만천원',
#   '엘지',
#   '이노',
#   '만원',
#   '삼성',
#   '전기',
#   '만원',
#   '삼성',
#   '에스',
#   '에스',
#   '만만원',
#   '삼성',
#   '생명',
#   '원내',
#   '이렇다',
#   '뵈다',
#   '년차',
#   '주식',
#   '경력',
#   '이다',
#   '한번',
#   '믿다',
#   '보다',
#   'ㅎㅎ'],
#  ['오늘', '오늘', '종가'],
#  ['막판', '슈팅', '하나', '날다', '버리다', '오늘', '종가', '이다'],
#  ['모르다',
#   '주리다',
#   '생키',
#   '이종',
#   '나다',
#   '알다',
#   '리스트',
#   '분석',
#   '보다',
#   '자다',
#   '알다',
#   '방송',
#   '없다',
#   '생키',
#   '평가',
#   '아니다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '미칭',
#   '그렇다',
#   '박살',
#   '나다'],
#  ['카카오',
#   '근거리',
#   '배송',
#   '물류',
#   '혁신',
#   '카카오',
#   '기반',
#   '시행',
#   '되다',
#   '때문',
#   '국민',
#   '장점',
#   '이용',
#   '많다',
#   '투자',
#   '비용',
#   '들다',
#   '않다',
#   '인프라',
#   '구축',
#   '있다',
#   '장점',
#   '한국',
#   '에서',
#   '유일하다',
#   '카카오',
#   '있다',
#   '시스템',
#   '이다',
#   '물류',
#   '시스템',
#   '갖추다',
#   '위해',
#   '들어가다',
#   '엄청나다',
#   '쿠팡',
#   '매년',
#   '조원',
#   '적자',
#   '나다',
#   '보다',
#   '알다',
#   '있다',
#   '누구',
#   '쉬다',
#   '뛰어들다',
#   '없다',
#   '카카오',
#   '문제',
#   '해결',
#   '국민',
#   '모두',
#   '근거리',
#   '도보',
#   '배송',
#   '정월',
#   '주지',
#   '않다',
#   '수수료',
#   '받다',
#   '국민',
#   '모두',
#   '배송',
#   '기사',
#   '되다',
#   '전국',
#   '카카오',
#   '기사',
#   '이라고',
#   '가정',
#   '해보다',
#   '매일',
#   '엄청나다',
#   '수수료',
#   '카카오',
#   '매출',
#   '잡히다',
#   '되다',
#   '이미',
#   '인프라',
#   '국민',
#   '카카오',
#   '깔다',
#   '편하다',
#   '쉬다',
#   '누구',
#   '있다',
#   '카카오',
#   '으로도',
#   '무궁',
#   '발전',
#   '국내',
#   '최고',
#   '기업',
#   '되다',
#   '바라다'],
#  ['카카오',
#   '인수',
#   '마스',
#   '매각',
#   '상한',
#   '날아가다',
#   '호재',
#   '투자',
#   '정보',
#   '미스티',
#   '세계',
#   '최초',
#   '플랫폼',
#   '전세',
#   '계위',
#   '호재',
#   '내용',
#   '투자',
#   '정보',
#   '세계',
#   '위세',
#   '최초',
#   '호재',
#   '공시',
#   '바닥',
#   '찍다',
#   '대세',
#   '상승',
#   '상향',
#   '시작',
#   '세계',
#   '최초',
#   '플랫폼',
#   '계위',
#   '호재',
#   '공시',
#   '내용'],
#  ['올라가다',
#   '속도',
#   '굼뱅',
#   '이여',
#   '네이버',
#   '얼마나',
#   '가야',
#   '따르다',
#   '갈다',
#   '엠병니',
#   '대장',
#   '네이버',
#   '대장',
#   '반토막',
#   '카카오',
#   '정신차려라'],
#  ['개미', '들어오다', '배당', '있다', '아니다'],
#  ['아가리', '벌리다', '들어왓', '손절'],
#  ['시간', '폭등', '이네', 'ㄷㄷㄷ', '있다', 'ㄷㄷㄷ', '내일', '만원', '찍다', 'ㄷㄷㄷ'],
#  ['오늘', '매수', '라는'],
#  ['카카오',
#   '카카오',
#   '말고',
#   '있다',
#   '카톡',
#   '정권',
#   '에서',
#   '밀다',
#   '받다',
#   '다음',
#   '그딴',
#   '밖에',
#   '없다',
#   '네이버',
#   '크다'],
#  ['오늘',
#   '씹다',
#   '재다',
#   '상한',
#   '가왜',
#   '가다',
#   '야다',
#   '익절',
#   '임오',
#   '부터',
#   '음식',
#   '배송',
#   '시작',
#   '인데',
#   '씹다',
#   '호재',
#   '에도',
#   '주가',
#   '이래'],
#  ['결제',
#   '서비스',
#   '네이버',
#   '토스',
#   '페이',
#   '압도',
#   '인터넷',
#   '은행',
#   '토스',
#   '뱅크',
#   '압도',
#   '승리',
#   '카카오',
#   '뱅크',
#   '저금',
#   '이다',
#   '적금',
#   '이다',
#   '바리',
#   '많다',
#   '토스',
#   '그냥',
#   '무조건',
#   '중간',
#   '넣다',
#   '뺏다',
#   '자유',
#   '직접',
#   '써다',
#   '보다',
#   '결제',
#   '서비스',
#   '네이버',
#   '페이',
#   '토스',
#   '페이',
#   '훨씬',
#   '좋다',
#   '들다',
#   '알다',
#   '사실'],
#  ['목표', '만원'],
#  ['김범수',
#   '기업',
#   '쪼개다',
#   '휴지',
#   '조각',
#   '장사',
#   '열사',
#   '상장',
#   '멈추다',
#   '삼성',
#   '보다',
#   '많다',
#   '카카오',
#   '열사',
#   '김범수',
#   '전략',
#   '열사',
#   '상장',
#   '휴지',
#   '전국',
#   '개미',
#   '한테',
#   '빨대',
#   '강성',
#   '친문',
#   '같다'],
#  ['잡다', '여전하다'],
#  ['이사분', '최저임금', '받다'],
#  ['공매도',
#   '잔고',
#   '매일',
#   '매일',
#   '열씨',
#   '밉다',
#   '공매도',
#   '치다',
#   '공매도',
#   '잔고',
#   '오히려',
#   '점차',
#   '점차',
#   '줄어들다',
#   '지난',
#   '금요일',
#   '에는',
#   '만주',
#   '공매도',
#   '때리다',
#   '잔고',
#   '오히려',
#   '주가',
#   '줄다',
#   '차이',
#   '만주',
#   '어디서',
#   '오다',
#   '크크',
#   '뻔하다',
#   '잉죄',
#   '우지',
#   '중인',
#   '가보다',
#   '쿠헬헬'],
#  ['내리막', '오름', '순이', '기다', '이제', '멘탈', '싸움'],
#  ['오늘', '상한', '가다', 'ㅋㅋㅋㅋㅋ'],
#  ['갓카오',
#   '다그',
#   '언젠가',
#   '늘다',
#   '비행',
#   '이미',
#   '시작',
#   '하고',
#   '있다',
#   '화이팅',
#   '갓카오',
#   '유지',
#   '추가',
#   '매수',
#   '예정',
#   '평단',
#   '만천'],
#  ['잦다'],
#  ['인천',
#   '좌동',
#   '엄마',
#   '이계인',
#   '펴다',
#   '쉰내',
#   '마이',
#   '쮸쮸',
#   '인천',
#   '가다',
#   '자동',
#   '부증',
#   '보종',
#   '조선족',
#   '연변',
#   '출신',
#   '진희',
#   '짖다',
#   '부사',
#   '켕킁켁',
#   '증상',
#   '심하다',
#   '매입',
#   '납품',
#   '단가',
#   '결제',
#   '대금',
#   '조작',
#   '핸드폰',
#   '도청',
#   '해킹',
#   '매달',
#   '복지관',
#   '물품',
#   '매년',
#   '경품',
#   '결제',
#   '대금',
#   '에서',
#   '착취',
#   '인조',
#   '묵다',
#   '돼지',
#   '등뼈',
#   '감자탕',
#   '되다',
#   '정상',
#   '아니다',
#   '힁선',
#   '물컹물컹',
#   '주물럭주물럭',
#   '거림',
#   '소리',
#   '아직도',
#   '맴돔',
#   '경리',
#   '여직원',
#   '엉덩이',
#   '판촉',
#   '여직원',
#   '강제',
#   '포옹',
#   '직원',
#   '내다',
#   '걷어차다',
#   '가다',
#   '개악',
#   '덕질',
#   '심하다',
#   '본인',
#   '혓바닥',
#   '대기',
#   '날리다',
#   '펴다',
#   '쉰내',
#   '이하이하이',
#   '바디',
#   '버디버디',
#   '버디',
#   'ㅋㅋ'],
#  ['거바', '카카오', '보단', '네이버', '라고', 'ㅋㅋ'],
#  ['거바', '카카오', '보단', '네이버', '라고', '카카오', '간다', '보다'],
#  ['올해', '지랄', '해도', '가기', '힘들다', 'ㅋㅋㅋ', '수익', '이나', '먹다', '만이', 'ㅋㅋ'],
#  ['짜다', '한번', '보여주다', '진입', '좋다'],
#  ['성탄절',
#   '토요일',
#   '일요',
#   '일일',
#   '경우',
#   '월요일',
#   '대체공휴일',
#   '지정',
#   '해주다',
#   '성탄절',
#   '토요일',
#   '일요',
#   '일일',
#   '경우',
#   '월요일',
#   '대체공휴일',
#   '지정',
#   '해주다'],
#  ['매집', '완료', '오늘', '까지', '도전'],
#  ['커버', '정신', '없다', '군종', '빠지다', '급등', '나오다'],
#  ['카카오', '끝나다'],
#  ['알다', '주다', '프로', '보다'],
#  ['어차피', '오르다', '털리다', '돼다', '그동안', '지루', '지불', '시작', '돼다'],
#  ['카카오', '암흑', '끝나다', '무슨', '일이', '이제', '다시', '점를', '가다'],
#  ['가다', '잡다', '매도', '카카오'],
#  ['빅뉴스',
#   '없다',
#   '공매도',
#   '때문',
#   '오르다',
#   '다그',
#   '묻다',
#   '두다',
#   '년후',
#   '수십',
#   '되어다',
#   '윤석렬',
#   '공매도',
#   '손보',
#   '겠다',
#   '피아',
#   '주머니',
#   '인데',
#   '검다',
#   '머리',
#   '외국인',
#   '연금',
#   '공매도',
#   '쯧쯧'],
#  ['살리다', '이다', '탈출', '기회', '줄다'],
#  ['이르다', '빠지다', 'ㅋㅋㅋ', '뻔하다', '깨깨'],
#  ['역전', '서막'],
#  ['번째', '물어보다', '평단', '만원', '마르다', '제발'],
#  ['떨어지다',
#   '추다',
#   '어느덧다',
#   '수익',
#   '떨구다',
#   '계속',
#   '추다',
#   '이제',
#   '수익',
#   '이네',
#   'ㅋㅋㅋ',
#   '오늘',
#   '좋다',
#   '이번',
#   '까지',
#   '가보다'],
#  ['이다', '쓰레기', '카카오'],
#  ['차량',
#   '반도체',
#   '유니',
#   '퀘스트',
#   '작년',
#   '대비',
#   '프로',
#   '영업',
#   '이익',
#   '증가',
#   '차량',
#   '반도체',
#   '유니',
#   '퀘스트',
#   '작년',
#   '대비',
#   '프로',
#   '영업',
#   '이익',
#   '증가'],
#  ['빨리',
#   '빨리',
#   '매수',
#   '으로는',
#   '계속',
#   '올라가다',
#   '빨리',
#   '빨리',
#   '추가',
#   '매수',
#   '하자',
#   '빨리',
#   '빨리',
#   '타다',
#   '하자'],
#  ['카톡', '카톡'],
#  ['카카오',
#   '고고',
#   '오늘',
#   '쭉쭉',
#   '상한',
#   '가다',
#   '느낌',
#   '좋다',
#   '추가',
#   '매수',
#   '타다',
#   '하자',
#   '화이팅'],
#  ['불기둥',
#   '만들다',
#   '오늘',
#   '일선',
#   '빨갛다',
#   '불기둥',
#   '만들다',
#   '최근',
#   '며칠',
#   '동안',
#   '상승',
#   '노력',
#   '거품',
#   '되다',
#   '외인',
#   '기관',
#   '이여',
#   '들어오다'],
#  ['네이버', '에서', '팔고', '카카오', '일전', '넘어오다', '신의한수'],
#  ['항상', '같다', '패턴', '이다', '급락', '위해', '오늘', '올리다', '오늘', '잡고', '나가다'],
#  ['살리다', '본전'],
#  ['네이버', '에서', '팔고', '우쭈쭈쭈'],
#  ['빨리', '빨리', '올라가다', '쭉쭉쭉', '올라가다'],
#  ['프로', '카카오', '오늘', '넘치다'],
#  ['오예', 'ㅎㅎㅎㅎ'],
#  ['일선', '확실하다', '뚫다', '최소', '까지', '간다', '붙잡다', '있다'],
#  ['카카오', '끝나다', '알다'],
#  ['하하', '하하', '삼전', '보내다', '처럼', '진짜', '카카오', '이다', 'ㅋㅋ'],
#  ['외국인', '기관', '쌍끌이', '매수', '빨리', '빨리', '상한', '가로', '오라'],
#  ['이제', '본전', '오다', '가다', '카카오'],
#  ['신용',
#   '매다',
#   '먹다',
#   '가다',
#   '신용',
#   '오다',
#   '익절',
#   '모간',
#   '들어오다',
#   '왠지',
#   '불안',
#   '오르다',
#   '원금',
#   '복구',
#   '되다',
#   '쫄려',
#   '총알',
#   '챙기다',
#   '놓다'],
#  ['만원', '까지', '홀딩좀', '가져가다', '한주', '매도', '없다'],
#  ['인데', '언제', '오다', 'ㅋㅋ', '제곧내'],
#  ['상봉', '정말'],
#  ['가보다', '가보다', '가다'],
#  ['감흥', '감다', '없다', '미치다', '카카오'],
#  ['지금',
#   '최고',
#   '가다',
#   '팔자',
#   '어차피',
#   '오후',
#   '내다',
#   '가유',
#   '한두',
#   '나팔',
#   '사람',
#   '어서',
#   '팔다',
#   '안팔',
#   '지만'],
#  ['사주', '구입', '일이'],
#  ['넘다', '들다', '오늘', '끄다', '까오', '떵싸'],
#  ['빨리', '빨리', '타다', '재산', '몰다', '이다', '몰다', '상한', '라이'],
#  ['다음주', '매도', '고로', '다음주', '매수'],
#  ['타다', '파다', '말다', '백만원', '수익', '고민', '이다'],
#  ['번가', 'ㅋㅋㅋㅋ'],
#  ['오늘',
#   '오르다',
#   '이유',
#   '개국',
#   '때문',
#   '카카오',
#   '오전',
#   '기준',
#   '전일',
#   '대비',
#   '오른',
#   '거래',
#   '되다',
#   '있다',
#   '카카오',
#   '한때',
#   '신저',
#   '기록',
#   '쓰다',
#   '원대',
#   '하향',
#   '카카오',
#   '주가',
#   '끌다',
#   '올리다',
#   '외국인',
#   '이다',
#   '외국인',
#   '지난',
#   '부터',
#   '까지',
#   '나흘',
#   '매수',
#   '하고',
#   '있다',
#   '카카오',
#   '지난해',
#   '월일',
#   '만원',
#   '까지',
#   '거래',
#   '돼다',
#   '지난달',
#   '만원',
#   '까지',
#   '떨어지다',
#   '주가',
#   '반토막',
#   '나다',
#   '전날',
#   '미국',
#   '증시',
#   '기술',
#   '주가',
#   '대폭',
#   '반등',
#   '점도',
#   '카카오',
#   '주가',
#   '상승세',
#   '도움',
#   '돼다',
#   '미국',
#   '연방',
#   '준비',
#   '제도',
#   '긴축',
#   '속도',
#   '조절',
#   '가능성',
#   '도세',
#   '몰리다',
#   '미국',
#   '기술',
#   '자금',
#   '몰리다'],
#  ['오늘', '느낌', '좋다', '기대다'],
#  ['햄볶', '연휴', '만들다', '좋다', '연휴', '길다', '햄볶', '크다'],
#  ['평단', '많다', '가요'],
#  ['평단', '에서', '팔고', '다시', '진입', '사람', '다나'],
#  ['무증', '나먼', '재료', '나오다'],
#  ['이렇게', '일만', '랏음', '좋다'],
#  ['점점', '떨어지다', '보다', 'ㅋㅋㅋㅋ', 'ㅋㅋㅋㅋ'],
#  ['보다',
#   '점점',
#   '밀리다',
#   '끄다',
#   '끄다',
#   '후퇴',
#   '지금',
#   '이라도',
#   '건지다',
#   '에이',
#   '아깝다',
#   '후회',
#   '말고'],
#  ['카카오', '보단', '분하다', '네이버', 'ㅋㅋ', '대세', '카카오', '페이', '뱅크', '게임', '나눠지다'],
#  ['어허', '라니깐', 'ㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋ'],
#  ['힘없다', '정권', '바뀌다'],
#  ['그렇다', '그렇다', '이제', '부터', '내리다'],
#  ['다시', '내다', '올라가다', '영차', '영차', '올라가다'],
#  ['놓다', '지금', '시점', '에서', '흐르다', '받다', '하고프다', '정신', '똑땍', '챙기다', '올라오다'],
#  ['하수', '장기', '투자', '보다', '개미', '이래서', '돼다'],
#  ['라라', '동안', '치다', '맞다', '공매도', '치다', '맞다', '차례'],
#  ['평단', '올리다', '해안', '올리다', '선배', '들다', '어떻다', '생각', '평단'],
#  ['외인', '기관', '수중', '팔고', 'ㅋㅋㅋㅋ', 'ㅋㅋㅋㅋ', '월요일', '떨어지다', '사다', 'ㅋㅋㅋㅋ'],
#  ['주식', '간단하다', '만원', '이상', '고갈', '사람', '사고', '만원', '빠지다', '같다', '사람', '팔다'],
#  ['카카오', '호재', '발표', '전기', '만빵', '까지는', '무난', '상승'],
#  ['일단',
#   '도망',
#   '가라',
#   '상책',
#   '이다',
#   '현재',
#   '분위기',
#   '지금',
#   '분위기',
#   '시가',
#   '갈수록',
#   '계속',
#   '꼬리',
#   '밀리다',
#   '도망',
#   '가라',
#   '현재',
#   '시간'],
#  ['개미', '들다', '오르다', '손절', '조금', '랏다', '던지기', 'ㅋㅋㅋㅋㅋ'],
#  ['공매도', '모간', '오늘', 'ㅅㄱ'],
#  ['장투',
#   '에겐',
#   '맞다',
#   '이지만',
#   '단기',
#   '투자',
#   '오늘',
#   '처럼',
#   '많이',
#   '오르다',
#   '팔고',
#   '이삼일',
#   '하락',
#   '살다',
#   '좋다',
#   '누가',
#   '이기다',
#   '아무',
#   '모르다',
#   '대부분',
#   '투하',
#   '사람',
#   '이기다'],
#  ['오잉', '다야', '상봉', '치다'],
#  ['종가', '사면', '월요일', '먹다'],
#  ['아오', '시초', '던지다', '푼돈', '벌다', '좋다', '던지다', '올라가다', 'ㅠㅠ', '아프다'],
#  ['폭등', '우와', 'ㄷㄷ'],
#  ['대다',
#   '상승',
#   '대다',
#   '상승',
#   '대다',
#   '상승',
#   '진입',
#   '예정',
#   '상승',
#   '모두',
#   '반납',
#   '상승',
#   '까지',
#   '밀리다',
#   '오늘',
#   '종가',
#   '까지',
#   '대다',
#   '상승',
#   '모두',
#   '반납',
#   '예상',
#   '시간',
#   '꼬리',
#   '이쁘다',
#   '달다',
#   '캔들',
#   '최악',
#   '캔들',
#   '만들다',
#   '위험',
#   '리스크',
#   '관리'],
#  ['쓰레기',
#   'ㅅㄲ',
#   '사주다',
#   '가격',
#   '높아지다',
#   '멈추다',
#   '사주다',
#   '떨어지다',
#   '떨어지다',
#   '쓰레기',
#   '다시',
#   '매수',
#   '시작',
#   '끼다',
#   '가하다',
#   '쓰레기',
#   '한테',
#   '물량',
#   '내주다',
#   '말다'],
#  ['일단',
#   '매도',
#   '관망',
#   '시간',
#   '지금',
#   '이라도',
#   '일단',
#   '매도',
#   '관망',
#   '보합',
#   '까지',
#   '밀리다',
#   '시간',
#   '일단',
#   '매도',
#   '진입',
#   '혹은',
#   '기회',
#   '포착',
#   '가지다',
#   '오늘',
#   '상승',
#   '모두',
#   '반납'],
#  ['크다', '회사', '운영', '들다', '하고', '있다'],
#  ['가다', '어제', '사다', 'ㅂㄷㅂㄷ', '느껴지다'],
#  ['바닥',
#   '찍다',
#   '반등',
#   '보다',
#   '하수',
#   '추락',
#   '날개',
#   '있다',
#   '다시',
#   '추락',
#   '일단',
#   '자리',
#   '자가',
#   '중단',
#   '바닥',
#   '보다'],
#  ['매수', '만원', '찍다', '기부'],
#  ['떨어지다',
#   '울다',
#   '떨어지다',
#   '만오',
#   '오르다',
#   'ㅜㅜ',
#   '이제',
#   '정말',
#   '벗어나다',
#   '싶다',
#   '동안',
#   '너무',
#   '힘들다',
#   '제발',
#   '누굴',
#   '원망하다',
#   '싶다',
#   '이고',
#   '오르다',
#   '오르다',
#   '같다',
#   '않다',
#   '오르다',
#   '고원',
#   '떨어지다',
#   '있다',
#   '오르다',
#   '프로',
#   '올려주다'],
#  ['지수', '보다', '강하다'],
#  ['이제',
#   '부터',
#   '출발',
#   '끄다',
#   '긍정',
#   '생각',
#   '삼성',
#   '전자',
#   '보다',
#   '좋다',
#   '삼전',
#   '대로',
#   '감다',
#   '평생',
#   '만이',
#   '주식',
#   '숫자',
#   '한민',
#   '민국',
#   '인구',
#   '되다',
#   '망하다',
#   '만주',
#   '싸다',
#   '오르다',
#   '삼전',
#   '이다'],
#  ['외국인',
#   '기관',
#   '쌍끌이',
#   '매수',
#   '올라가다',
#   '어차피',
#   '올라가다',
#   '빨리',
#   '빨리',
#   '올라가다',
#   '종가',
#   '에는',
#   '장대',
#   '양봉',
#   '만들다',
#   '보다',
#   '상한',
#   '가로',
#   '출발',
#   '라이'],
#  ['매수',
#   'ㅡㅡ',
#   '매수',
#   '생각',
#   '만해',
#   '멋쩌',
#   '매수',
#   '들어가다',
#   '잔고',
#   '털다',
#   'ㅡㅡ',
#   '손자',
#   '장가',
#   '갈다',
#   '매도',
#   '이십',
#   'ㅡㅡㅡ'],
#  ['증시',
#   '폭락',
#   '문전',
#   '있다',
#   '인플레',
#   '금리',
#   '인상',
#   '검다',
#   '구름',
#   '몰려오다',
#   '저가',
#   '라고',
#   '들어가다',
#   '어둠',
#   '빠지다',
#   '허다',
#   '우적',
#   '린다',
#   '조심'],
#  ['개미', '유튜브', '개미', '시청', '무료', '종목', '추천', '매다', '알다'],
#  ['평단', '가원', '만원', '매도', 'ㅠㅠ'],
#  ['카카', '배당', '많이', '주다', '래야', '주식', '많이', '사지'],
#  ['크다', '아가리', '어어어어', 'ㅋㅋ', '아가리', '쪼오옥', '아리'],
#  ['오늘',
#   '같다',
#   '오프',
#   '올라가다',
#   '오늘',
#   '같다',
#   '장애',
#   '인간',
#   '프로',
#   '올라가다',
#   '빨리',
#   '빨리',
#   '올라가다'],
#  ['질질',
#   '흐르다',
#   '내리다',
#   '반토막',
#   '카카오',
#   '조정만',
#   '이다',
#   '고마',
#   '가다',
#   '동안',
#   '주주',
#   '죽이다',
#   '공매도',
#   '죽다',
#   '지다',
#   '그게',
#   '정의'],
#  ['올라가다', '부정', '론자', '댓글', '잘알다', '보임', '뇌동', '매매', '한심하다', '없다', '보임'],
#  ['카카오', '독점', '택시', '때문', '주가', '가쉽', '오르다', '같다', '않다'],
#  ['카카오', '미국', '나스닥', '상장', 'ㅋㅋㅋ'],
#  ['에이', '파다', '개갓', '카카오', '밟다'],
#  ['만원', '에서', '엄첨', '빠지다', '진짜', '어이없다'],
#  ['물들다',
#   '오다',
#   '들다',
#   '탈출',
#   '들어오다',
#   '구명조끼',
#   '라도',
#   '입다',
#   '탈출',
#   '침몰',
#   '있다',
#   '자네',
#   '손해',
#   '시간'],
#  ['평단', '가다', '옵빵'],
#  ['사부작사부작', '리지', '않다', '기어', '오르다', 'ㅡㅡㅡㅋㅋ'],
#  ['오르다', '인들', '수익', '늘어나다', '차잔', '보다', '에서', '물리다', '불쌍하다', '리지', '마르다'],
#  ['점점', '내려오다', '보합', '갈다', '같다', 'ㅋㅋ'],
#  ['오다',
#   '팔고',
#   '튀기다',
#   '자다',
#   '평단',
#   '이다',
#   '먹다',
#   '던지다',
#   '나오다',
#   '숫자',
#   '안되다',
#   '의미',
#   '없다',
#   '다행',
#   '이네',
#   '뿐이다',
#   '다음',
#   '뵈다'],
#  ['진짜',
#   '재수없다',
#   '질질',
#   '흐르다',
#   '반토막',
#   '카카오',
#   '진짜',
#   '싫다',
#   '민주당',
#   '송영길',
#   '시발',
#   '이다'],
#  ['금지', '일선', '에서', '매수', '준비'],
#  ['사다', '그날', '바로', '물리다', '버리다'],
#  ['진짜',
#   '질질',
#   '흐르다',
#   '장마',
#   '보합',
#   '되다',
#   '공매도',
#   '오늘',
#   '싸다',
#   '공매도',
#   '만을',
#   '위해',
#   '존재',
#   '시장',
#   '개한민국'],
#  ['서다', '흑우', '없다'],
#  ['어제',
#   '담다',
#   '남다',
#   '몰다',
#   '그렇다',
#   '그래도',
#   '하루',
#   '만에',
#   '밥값',
#   '벌다',
#   '가다',
#   '매도',
#   '완료'],
#  ['만큼', '쉬다', '올라가다', '이제', '빨리', '빨리', '올라가다', '마지막', '버스', '빨리', '타라', '출발'],
#  ['한국',
#   '조선해',
#   '나르다',
#   '셀트리온',
#   '나르다',
#   '자다',
#   '보고오다',
#   '패턴',
#   '있다',
#   '주가',
#   '어떻다',
#   '나다',
#   '그냥',
#   '한번',
#   '봉우리',
#   '만들다',
#   '주다',
#   '가지',
#   '않다',
#   '시장',
#   '마무리',
#   '주도',
#   '주가',
#   '다시',
#   '복귀',
#   '하고',
#   '나서다',
#   '사이클',
#   '끝나다',
#   '쌍봉',
#   '만들다',
#   '길이',
#   '오늘',
#   '던지다',
#   '흑우',
#   '다시다',
#   '살다'],
#  ['모간', '사다', '한번', '매도', 'ㅋㅋ', '장난', '오지', 'ㅋㅋ'],
#  ['한번', '매도', '아니다', '커버', '이제', '공매도', '똥줄', '타다', 'ㅋㅋㅋ'],
#  ['외인',
#   '한국',
#   '주식',
#   '나다',
#   '사다',
#   '이유',
#   '알다',
#   '다다르다',
#   '떨어지다',
#   '왕창',
#   '놓다',
#   '달러',
#   '하락',
#   '환차익',
#   '보다',
#   '지금',
#   '우량',
#   '반토막',
#   '나서다',
#   '매집',
#   '너무',
#   '좋다',
#   '지반',
#   '대로',
#   '서학',
#   '개미',
#   '반토막',
#   '나다',
#   '주가',
#   '오르다',
#   '달러',
#   '하락',
#   '원화',
#   '전시',
#   '손해',
#   '보다',
#   '지금',
#   '한국',
#   '주식',
#   '사다',
#   '이유'],
#  ['신용', '주다', '공매도', '상환'],
#  ['외인',
#   '슬슬',
#   '빼다',
#   '지금',
#   '외인',
#   '지금',
#   '물량',
#   '미장',
#   '열리다',
#   '넣다',
#   '슬슬',
#   '빼다',
#   '종가',
#   '후반',
#   '정착'],
#  ['아가리'],
#  ['애증', '끄다', '오사', '떨어지다', '팔면', '오르다', 'ㅎㅎ'],
#  ['만원', '까지', '거의', '수익', '이여', '야하다', 'ㅋㅋ', '노답', '카카오', 'ㅋㅋ'],
#  ['아직', '빠지다', '토끼', 'ㅌㅌㅌ'],
#  ['아침', '분명', '점를', '달리다', '아니다', '다시', '점를', '달리다'],
#  ['카카오', '묶이다', '있다', '자금', '묶이다', '있다', '애증', '카카오'],
#  ['가라', '그대로'],
#  ['카카오',
#   '카카오',
#   'ㅋㅋㅋ',
#   '종가',
#   '다가오다',
#   '주가',
#   '떨어지다',
#   '능력',
#   '이다',
#   'ㅋㅋㅋ',
#   '주주',
#   '불쌍하다',
#   '잡다',
#   '물리다'],
#  ['진짜', '보합', '가르다', '반토막', '카카오', '진짜', '찌다', '따다'],
#  ['역시', '잡다', '오르다', '가다', 'ㅆㄹㄱ', '기업'],
#  ['종가', '보합', '이다', '같다', '이노베이션', '자다', '나르다'],
#  ['넘다',
#   '들다',
#   '치다',
#   '올려놓다',
#   '왕창',
#   '파다',
#   '그러니까',
#   '사다',
#   '항상',
#   '넘다',
#   '들다',
#   '술수',
#   '당하다',
#   '있다'],
#  ['혹시', '역시', '모간', '모간'],
#  ['크다',
#   '만에',
#   '들르다',
#   '그때',
#   '보다',
#   '더죽',
#   '쑤다',
#   '있다',
#   'ㅋㅋㅋㅋ',
#   '코털',
#   '이랑',
#   '문어',
#   '대가리',
#   '자빠지다'],
#  ['종가', '예측', '시스템', '젠장'],
#  ['월요일', '기대하다', '털리다', '구경해'],
#  ['종가',
#   '슈팅',
#   '하나',
#   '날다',
#   '버리다',
#   '마지막',
#   '다해',
#   '슈팅',
#   '하나',
#   '종가',
#   '날다',
#   '버리다',
#   '오늘',
#   '종가',
#   '슈팅',
#   '하나',
#   '날다',
#   '이다'],
#  ['자리', '오늘', '아침', '장대', '양봉', '절반', '이라', '모건', '절대', '내주다'],
#  ['종가', '예측', '시스템', '거의', '추다', 'ㅋㅋ'],
#  ['ㅋㅋㅋ', '역시', '매물'],
#  ['축하', '드리다', '시작', '오르다'],
#  ['시호', '빼다', '올리다', '빼다', '같다', 'ㅋㅋ'],
#  ['제이', '모간', '만이', '단타', '쟁이', '브랄놈'],
#  ['월요일', '간데잉', 'ㅋㅋㅋㅋ'],
#  ['솔직하다',
#   '송영길',
#   '아니다',
#   '벌써',
#   '찍다',
#   '송영길',
#   '믿다',
#   '없이',
#   '카카오',
#   '골목',
#   '상권',
#   '침해',
#   '좋다',
#   '않다',
#   '발언',
#   '금융위',
#   '금감원',
#   '공정',
#   '거래',
#   '위원회',
#   '까지',
#   '하루',
#   '돌아가다',
#   '위협',
#   '이유',
#   '놀다',
#   '여기다',
#   '배달',
#   '민족',
#   '쿠팡',
#   '다이소',
#   '골목',
#   '상권',
#   '상관',
#   '없다',
#   '가세',
#   '대다',
#   '미스터리',
#   '송영길',
#   '뜬금',
#   '없다',
#   '카카오',
#   '공격',
#   '공매도',
#   '세력',
#   '결탁',
#   '또는',
#   '누군가',
#   '로부터',
#   '이용',
#   '당하다',
#   '시작',
#   '보다',
#   '지금',
#   '아무',
#   '없다',
#   '듯이',
#   '조용하다',
#   '이유',
#   '쯧쯧',
#   '쯩온플',
#   '법도',
#   '선거',
#   '흐지브지되',
#   '이제',
#   '다시',
#   '카카오',
#   '사업',
#   '하나',
#   '하나',
#   '진행',
#   '되다',
#   '떨어지다',
#   '이유',
#   '있다'],
#  ['마지막', '배팅', '이다', '올라가다', '마지막', '다해', '올라가다', '카카오', '화이팅'],
#  ['송영길', '치다', '나락', '아무', '아니다', '민심', '심판'],
#  ['플랫폼',
#   '규제',
#   '떠들다',
#   '더듬다',
#   '지선',
#   '참패',
#   '네이버',
#   '카카오',
#   '주주',
#   '이나',
#   '찍다',
#   '긋다',
#   '찢다',
#   '같다',
#   '방탄',
#   '조끼',
#   '입히다',
#   '역풍',
#   '치다',
#   '맞다'],
#  ['지금', '부터는', '양봉', '모으다', '기다', '아니다', 'ㅎㅎ'],
#  ['송영길', 'ㅋㅋ', '카카오', '나락'],
#  ['시간', '폭등', '이네', 'ㄷㄷㄷ', '있다', 'ㄷㄷㄷ', '내일', '만원', '찍다', 'ㄷㄷㄷ'],
#  ['연기금',
#   '형님',
#   '입성',
#   '미만',
#   '파다',
#   '아니다',
#   '개미',
#   '털리다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '흑우',
#   '생키'],
#  ['입성', '영차', '영차', '영차'],
#  ['송영길'],
#  ['카카오',
#   '지주회사',
#   '사면',
#   '후회',
#   '다물다',
#   '분할',
#   '예정',
#   '종목',
#   '모빌리티',
#   '코마',
#   '라이온하트',
#   '여기',
#   '스톡옵션',
#   '까지',
#   '직원',
#   '부터',
#   '사심',
#   '없다',
#   '사주',
#   '파다',
#   '튀다'],
#  ['속보',
#   '테슬라',
#   '직원',
#   '줄이다',
#   '경기',
#   '침체',
#   '악화',
#   '되다',
#   '머스크',
#   '속보',
#   '테슬라',
#   '직원',
#   '줄이다',
#   '경기',
#   '침체',
#   '악화',
#   '되다',
#   '머스크',
#   '튜버',
#   '스펙',
#   '베스트'],
#  ['금모',
#   '앗다',
#   '물가',
#   '안정',
#   '마음',
#   '아야',
#   '전쟁',
#   '포탄',
#   '보다',
#   '무섭다',
#   '물가',
#   '폭등',
#   '이다',
#   '국가',
#   '물가',
#   '안정',
#   '여러',
#   '방책',
#   '갖다',
#   '제반',
#   '여러',
#   '국민',
#   '통찰',
#   '제어',
#   '제한',
#   '되다',
#   '뿐이다',
#   '국민',
#   '께서는',
#   '번의',
#   '엄중하다',
#   '혹독하다',
#   '수도',
#   '있다',
#   '물가',
#   '움직임',
#   '대해',
#   '우리',
#   '심연',
#   '마음',
#   '으로부터',
#   '모으다',
#   '기르다',
#   '크나크다',
#   '국난',
#   '극복',
#   '물가',
#   '안정',
#   '모두',
#   '슬기롭다',
#   '지혜',
#   '모으다',
#   '마음',
#   '모으다',
#   '야하다',
#   '이다',
#   '국민',
#   '마음',
#   '어디',
#   '금쪽',
#   '보다',
#   '우리',
#   '국난',
#   '극복',
#   '역사',
#   '없다'],
#  ['다음',
#   '유저',
#   '로서',
#   '그리고',
#   '한때',
#   '카카오',
#   '로서',
#   '조금',
#   '기다리다',
#   '언제',
#   '담다',
#   '싶다',
#   '애정',
#   '있다',
#   '회사',
#   '이다',
#   '이제',
#   '다음',
#   '아예',
#   '보내다',
#   '점점',
#   '불편하다',
#   '레이아웃',
#   '다음카카오',
#   '계정',
#   '과의',
#   '일괄',
#   '통합',
#   '강요',
#   '스러운',
#   '카카오',
#   '컨텐츠',
#   '유도',
#   '유저',
#   '과도',
#   '이용',
#   '제한',
#   '등더',
#   '이상',
#   '개인',
#   '매력',
#   '느끼다',
#   '위젯',
#   '지우다',
#   '버리다',
#   '간간히',
#   '메일',
#   '이나',
#   '확인',
#   '가다',
#   '이제',
#   '메리트',
#   '없다',
#   '음주주',
#   '되다',
#   '싶다',
#   '마음',
#   '갈다',
#   '버리다',
#   '같다',
#   '다른',
#   '투자',
#   '나은',
#   '같다'],
#  ['개인', '파다'],
#  ['오다', '오다', '물리다', '사람', '생각', '잠듭', '월요일', '보다'],
#  ['나스닥', '박다'],
#  ['오늘', '전량', '매도', '화요일', '힘들다', '수익', '내다', '현금', '확보', '차원'],
#  ['나스닥', '빅쇼', 'ㅡㅡ'],
#  ['해치다', '먹기', '바쁘다', '회사', '문어', '발상', '멈추다'],
#  ['카카오', '카카오'],
#  ['작년',
#   '겨울',
#   '버리다',
#   '작년',
#   '겨울',
#   '버리다',
#   '이명박',
#   '사서',
#   '이명박',
#   '박근혜',
#   '동안',
#   '천만원',
#   '오른',
#   '아파트',
#   '문재인',
#   '동안',
#   '억이',
#   '올라서다',
#   '작년',
#   '겨울',
#   '버리다',
#   '고향',
#   '작다',
#   '빌라',
#   '얻다',
#   '텃밭',
#   '가꾸다',
#   '조용하다',
#   '주식',
#   '하고',
#   '있다',
#   '요즘',
#   '하단',
#   '에서',
#   '분할',
#   '매수',
#   '시작',
#   '주식',
#   '종합',
#   '주가',
#   '지수',
#   '넘다',
#   '생각',
#   '이다'],
#  ['인플레이션',
#   '둔화',
#   '달러',
#   '약세',
#   '한국',
#   '법인세',
#   '인하',
#   '호재',
#   '쌓이다',
#   '최근',
#   '인플레이션',
#   '둔화',
#   '기조',
#   '달러',
#   '약세',
#   '전환',
#   '한국',
#   '법인세',
#   '인하',
#   '검토',
#   '악재',
#   '쌓이다',
#   '주식시장',
#   '점점',
#   '호재',
#   '생겨나다',
#   '있다',
#   '관련',
#   '해당',
#   '영향',
#   '주식시장',
#   '어떻다',
#   '작용',
#   '대하',
#   '자세하다',
#   '써다',
#   '틀리다',
#   '부분',
#   '이나',
#   '언해',
#   '야하다',
#   '내용',
#   '있다',
#   '해주다'],
#  ['금요일', '이다', '다음주', '폭락', '오다'],
#  ['인천',
#   '좌동',
#   '엄마',
#   '이계인',
#   '펴다',
#   '쉰내',
#   '마이',
#   '쮸쮸쮸',
#   '인천',
#   '가다',
#   '자동',
#   '부증',
#   '보종',
#   '조선족',
#   '연변',
#   '출신',
#   '진희',
#   '짖다',
#   '사수',
#   '켁킁',
#   '증상',
#   '심하다',
#   '매입',
#   '납품',
#   '단가',
#   '결제',
#   '대금',
#   '조작',
#   '핸드폰',
#   '도청',
#   '해킹',
#   '매달',
#   '복지관',
#   '물품',
#   '매년',
#   '경품',
#   '결제',
#   '대금',
#   '에서',
#   '착취',
#   '인조',
#   '묵다',
#   '돼지',
#   '등뼈',
#   '감자탕',
#   '되다',
#   '정상',
#   '아니다',
#   '이힁선',
#   '물컹물컹',
#   '주물럭주물럭',
#   '거림',
#   '소리',
#   '아직도',
#   '맴돔',
#   '경리',
#   '여직원',
#   '엉덩이',
#   '판촉',
#   '여직원',
#   '강제',
#   '포옹',
#   '직원',
#   '내다',
#   '걷어차다',
#   '가다',
#   '개악',
#   '덕질',
#   '심하다',
#   '본인',
#   '혓바닥',
#   '이희',
#   '대기',
#   '날리다',
#   '펴다',
#   '쉰내',
#   '이하이하이',
#   '바디',
#   '버디버디',
#   '버디',
#   'ㅎㅎㅎ'],
#  ['다시', '내려가다', '없다', '주식', '오르다', '리가', '있다'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['몰다', '빵햇', '늘다', '오다'],
#  ['카카오', '분할', '없다', '특기', '보여주다', '지물', '분할', '주주', '매도', '뒤통수', '해보다'],
#  ['무슨', '카카오', '망하다', '기업', 'ㅋㅌㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['오다', '카카오', '이제', '까지', '사다', '지금', '이네', '달이', '충분하다', '범수'],
#  ['카카오', '희망', '후회', '카카오', '존망', '종목'],
#  ['도대체',
#   '걸다',
#   '담배',
#   '피다',
#   '부모',
#   '없다',
#   '매너',
#   '지키다',
#   '역겹다',
#   '담배',
#   '냄새',
#   '때문',
#   '짜증나다',
#   '삶의질',
#   '떨어지다',
#   '층간소음',
#   '흡연',
#   '보행',
#   '흡연',
#   '도대체',
#   '걸다',
#   '담배',
#   '피다',
#   '부모',
#   '없다',
#   '매너',
#   '지키다',
#   '역겹다',
#   '담배',
#   '냄새',
#   '때문',
#   '짜증나다',
#   '삶의질',
#   '떨어지다',
#   '층간소음',
#   '흡연',
#   '보행',
#   '흡연'],
#  ['주환',
#   '원하다',
#   '범수',
#   '기부',
#   '이고',
#   '일단',
#   '투자',
#   '주주',
#   '부터',
#   '살리다',
#   '기부',
#   '번돈',
#   '내뱉다',
#   '나다',
#   '대로',
#   '하고'],
#  ['친일파',
#   '종특',
#   '씹덕',
#   '음란물',
#   '중독',
#   '씹다',
#   '노예',
#   '군대',
#   '직장',
#   '문화',
#   '자리',
#   '잡다',
#   '장본',
#   '인들',
#   '여자',
#   '제일',
#   '일본',
#   '가부장',
#   '남자',
#   '아갈',
#   '로는',
#   '허구',
#   '애국',
#   '보수',
#   'ㅇㅈㄹ',
#   '하지만',
#   '에선',
#   '일본',
#   '먹다',
#   '매국',
#   '노련'],
#  ['좋다',
#   '주식',
#   '이란',
#   '상승',
#   '오르다',
#   '주식',
#   '이다',
#   '하락',
#   '오르다',
#   '주식',
#   '이다',
#   '정도',
#   '모든',
#   '주식',
#   '정리',
#   '부터',
#   '주식',
#   '다시',
#   '관심',
#   '갖다',
#   '시작',
#   '이렇게',
#   '관심',
#   '갖다',
#   '않다',
#   '모든',
#   '주식',
#   '정리',
#   '다시',
#   '주식',
#   '시세',
#   '보다',
#   '때내',
#   '파다',
#   '가격',
#   '보다',
#   '오른',
#   '주식',
#   '이노',
#   '에코',
#   '프로비',
#   '머티리얼즈',
#   '에프',
#   '다른',
#   '종목',
#   '있다',
#   '있다',
#   '관심',
#   '가지다',
#   '주식',
#   '이런',
#   '이다',
#   '그렇다',
#   '언제',
#   '부자',
#   '되다',
#   '있다',
#   '좋다',
#   '하락',
#   '인데',
#   '다른',
#   '주식',
#   '떨어지다',
#   '오르다',
#   '있다',
#   '주식',
#   '좋다',
#   '주식',
#   '이라는',
#   '생각',
#   '들다',
#   '그렇다',
#   '카카오',
#   '좋다',
#   '주식',
#   '인가',
#   '코스',
#   '라니',
#   '늘다',
#   '주식',
#   '벌리다',
#   '가지',
#   '있다',
#   '이야기',
#   '내생',
#   '각운',
#   '네가지',
#   '어느',
#   '한가지',
#   '라도',
#   '없다',
#   '안되다',
#   '가지다',
#   '어떻',
#   '마련',
#   '있다',
#   '마련',
#   '수가',
#   '없다',
#   '준비',
#   '되어다',
#   '있다',
#   '사람',
#   '에겐',
#   '따르다',
#   '당신',
#   '준비',
#   '되어다',
#   '사람',
#   '인가'],
#  ['설거지',
#   '물리',
#   '평생',
#   '후회',
#   '다현',
#   '주가',
#   '에서',
#   '반토막',
#   '나다',
#   '바닥',
#   '박스',
#   '박박',
#   '기어',
#   '야하다',
#   '크다',
#   '기업',
#   '안되다',
#   '다행',
#   '대주',
#   '주가',
#   '해치다',
#   '먹다',
#   '주식',
#   '은상',
#   '아니다',
#   '장기',
#   '대세',
#   '하락',
#   '모름'],
#  ['네버',
#   '망하다',
#   '카카오',
#   '대등하다',
#   '위치',
#   '까지',
#   '성장',
#   '크다',
#   '다른',
#   '신규',
#   '회사',
#   '분투',
#   '주가',
#   '수십',
#   '올리다',
#   '해처',
#   '묵다',
#   '기수법',
#   '카카오',
#   '자회사',
#   '통한',
#   '수익',
#   '추다',
#   '차이다',
#   '어떤',
#   '기업',
#   '살아나다',
#   '좋다',
#   '건지다',
#   '아시'],
#  ['카카오',
#   '어떤',
#   '회사',
#   '인가',
#   '정부',
#   '굴복',
#   '에서',
#   '가입자',
#   '개인',
#   '정보',
#   '제공',
#   '이미',
#   '오래',
#   '돼다',
#   '알다',
#   '사람',
#   '당해',
#   '사람',
#   '알다',
#   '사실',
#   '보안',
#   '전혀',
#   '없다',
#   '이다',
#   '가치',
#   '없다'],
#  ['카카오', '살다', '좌빨'],
#  ['ㅋㅋ', '주말', '인데', '쉬다', 'ㅋㅋ', '나가다', '바람', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['아직', '타다', '다시', '오다'],
#  ['우크라이나',
#   '부역',
#   '한국',
#   '부역',
#   '차이',
#   '우크라이나',
#   '에서',
#   '러시아군',
#   '정보',
#   '제공',
#   '하고',
#   '안내',
#   '부역',
#   '처리',
#   '고심',
#   '이라',
#   '외신',
#   '전하',
#   '있다',
#   '이번',
#   '전쟁',
#   '원인',
#   '나토',
#   '동진',
#   '배후',
#   '미국',
#   '이다',
#   '비무장',
#   '민간인',
#   '보유',
#   '러시아군',
#   '전시',
#   '항해',
#   '초토화',
#   '당하다',
#   '일정',
#   '순응',
#   '재산',
#   '인명',
#   '보호',
#   '현명하다',
#   '행동',
#   '지는',
#   '차후',
#   '한국',
#   '에서는',
#   '친일',
#   '부역',
#   '들이다',
#   '이어서',
#   '양키',
#   '개짓',
#   '최고',
#   '애국',
#   '되어다',
#   '분단',
#   '반대',
#   '무차별',
#   '학살',
#   '하고',
#   '간첩',
#   '이라',
#   '조작',
#   '양키',
#   '개짓',
#   '충성',
#   '하니',
#   '침략',
#   '안방',
#   '차지',
#   '방범',
#   '하루',
#   '이상',
#   '강탈',
#   '하고',
#   '싸다',
#   '비료',
#   '뜯다',
#   '세기',
#   '지구',
#   '유일하다',
#   '전작권',
#   '없다',
#   '양키',
#   '괴뢰',
#   '형태',
#   '치욕',
#   '있다',
#   '치욕',
#   '모르다',
#   '계위',
#   '한국',
#   '소총',
#   '탈레반',
#   '한테',
#   '양키',
#   '개짓',
#   '이라니',
#   '우리',
#   '현명하다',
#   '외교',
#   '정상',
#   '국격',
#   '국익',
#   '챙기다',
#   '정당하다',
#   '국가',
#   '이뤄지다',
#   '오늘',
#   '양키',
#   '부역',
#   '들이다',
#   '안보',
#   '외치',
#   '침략',
#   '부역',
#   '혈안',
#   '이니',
#   '양키',
#   '온갖',
#   '수로',
#   '미군',
#   '심리',
#   '전단',
#   '코리아',
#   '미션',
#   '세다',
#   '운영',
#   '언론',
#   '통해',
#   '혼란',
#   '부추기다',
#   '혈안',
#   '이니',
#   '다시',
#   '양키',
#   '사냥개',
#   '정권',
#   '추다',
#   '의기',
#   '양양'],
#  ['욕심',
#   '많다',
#   '경기도',
#   '인구',
#   '수만',
#   '민주당',
#   '앞장서다',
#   '남북',
#   '도로',
#   '분도',
#   '하든',
#   '성남시',
#   '광주시',
#   '하남시',
#   '통합',
#   '광역시',
#   '만들다'],
#  ['인천공항',
#   '하늘',
#   '정체',
#   '해소',
#   '위해',
#   '서도',
#   '김포공항',
#   '필요',
#   '김포공항',
#   '기능',
#   '인천공항',
#   '청주공항',
#   '대폭',
#   '확장',
#   '불다',
#   '옮기다',
#   '서울',
#   '인천공항',
#   '고속',
#   '도로',
#   '대교',
#   '건설',
#   '서울',
#   '청주시',
#   '철도',
#   '건설',
#   '김포공항',
#   '짜다',
#   '주상',
#   '복합',
#   '채건',
#   '설다',
#   '비용',
#   '김포공항',
#   '재개발',
#   '수익',
#   '일부',
#   '충당'],
#  ['속보',
#   '유영',
#   '카카오',
#   '폭등',
#   '거대',
#   '유대',
#   '자본',
#   '이상',
#   '미국',
#   '하락',
#   '원하다',
#   '않다',
#   '바닥',
#   '확인',
#   '이제',
#   '부터',
#   '폭등',
#   '카카오',
#   '날아가다'],
#  ['카카오',
#   '해부',
#   '다른',
#   '주식',
#   '가치',
#   '비다',
#   '너무',
#   '고가',
#   '이다',
#   '카카오',
#   '뱅크',
#   '페이',
#   '게임'],
#  ['유엔',
#   '미국',
#   '대사',
#   '헤일리',
#   '고문',
#   '일전',
#   '에도',
#   '언급',
#   '가량',
#   '사용',
#   '아이디',
#   '용정',
#   '되어다',
#   '계몽',
#   '팔로',
#   '업다',
#   '쓸다',
#   '전체',
#   '보기',
#   '활용',
#   '주기',
#   '바라다'],
#  ['까지',
#   '계단',
#   '하락',
#   '차트',
#   '시세',
#   '한번',
#   '나오다',
#   '주식',
#   '고향',
#   '간다',
#   '명언',
#   '있다',
#   'ㅋㅋ',
#   '세력',
#   '계단',
#   '하락',
#   '막히다',
#   '물량',
#   '넘기다',
#   '지금',
#   '이라도',
#   '카카오',
#   '버리다',
#   '나중',
#   '큰일',
#   '나다'],
#  ['알다', '주다', '빨다', '인지', '나중', '알다'],
#  ['카카오', '엔터', '빨리', '상장', '바라다', '빨리'],
#  ['카카오', '알다', '알다', '박다', 'ㅋㅋㅋㅋ', '짜증나다', '그렇다', '손절', '들다', 'ㅋㅋㅋㅋ'],
#  ['보유',
#   '카카오',
#   '바닥',
#   '폭등',
#   '거대',
#   '유대',
#   '자본',
#   '이상',
#   '미국',
#   '하락',
#   '원하다',
#   '않다',
#   '바닥',
#   '확인',
#   '이제',
#   '부터',
#   '폭등',
#   '미국',
#   '주식',
#   '카카오',
#   '날아가다'],
#  ['직원',
#   '요구사항',
#   '없다',
#   '만족',
#   '모르다',
#   '회사',
#   '에서',
#   '지다',
#   '들다',
#   '닦다',
#   '휴지',
#   '내놓다',
#   '같다'],
#  ['카카오',
#   '유튜브',
#   '처럼',
#   '대폭',
#   '손질',
#   '하자',
#   '다큐',
#   '인사이트',
#   '다큐',
#   '시리즈',
#   '동물',
#   '극장',
#   '단짝',
#   '영상',
#   '앨범',
#   '기행',
#   '전세계',
#   '보내다',
#   '좋다',
#   '영상',
#   '너무',
#   '많다',
#   '한국',
#   '모든',
#   '영상',
#   '콘텐츠',
#   '카카오',
#   '담다',
#   '유튜브',
#   '실어',
#   '서비스',
#   '좋다',
#   '카카오',
#   '구독',
#   '자수',
#   '너무',
#   '초라하다',
#   '카카오',
#   '유튜브',
#   '독자',
#   '천만',
#   '목표',
#   '삼다'],
#  ['알다',
#   '주다',
#   '여기',
#   '카카오',
#   '카카오',
#   '대리',
#   '택시',
#   '뱅크',
#   '주식',
#   '기타',
#   '서비스',
#   '사용',
#   '흑우',
#   '없다',
#   '지그',
#   '때놈',
#   '이나',
#   '쪽바리',
#   '아니다',
#   '사람',
#   '없다',
#   '주식',
#   '반토막',
#   '나서다',
#   '받다',
#   '그게',
#   '카카오',
#   '잘못',
#   '이냐',
#   '부안',
#   '하고',
#   '전략',
#   '없다',
#   '대가리',
#   '나쁘다',
#   '잘못',
#   '이냐',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '계좌',
#   '회복',
#   '되다',
#   '바라다',
#   '열심히',
#   '해보다',
#   '노력',
#   '하고',
#   '남탓',
#   '치고',
#   '돈버는놈',
#   '보다',
#   '외국인',
#   '대한민국',
#   '살기',
#   '좋다',
#   '나라',
#   '라고',
#   '극찬',
#   '조선',
#   '개한민국',
#   '그렇다',
#   '인생',
#   '같다',
#   '나라',
#   '생각',
#   '말고',
#   '어떻',
#   '부자',
#   '되다',
#   '어떻',
#   '잘살다',
#   '있다',
#   '연구',
#   '하고',
#   '노력',
#   '해보다',
#   '옛날',
#   '국민',
#   '대부분',
#   '재테크',
#   '모르다',
#   '열심히',
#   '월급',
#   '모으다',
#   '평생',
#   '빠지다',
#   '해보다',
#   '지금',
#   '하고',
#   '다르다',
#   '같다',
#   '장단점',
#   '있다',
#   '노력',
#   '하고',
#   '문명',
#   '발전',
#   '아무렇다',
#   '않다',
#   '당연하다',
#   '생각',
#   '나빠지다',
#   '생각',
#   '우리나라',
#   '살기',
#   '좋다',
#   '은나라',
#   '마음',
#   '바꾸다',
#   '보다',
#   '계좌',
#   '달라지다'],
#  ['신용',
#   '공매도',
#   '주다',
#   '좋다',
#   '흐름',
#   '나스닥',
#   '반등',
#   '정안',
#   '나오다',
#   '버티다',
#   '보다',
#   '바닥',
#   '물가',
#   '점론',
#   '달러',
#   '하락',
#   '전환'],
#  ['카카오'],
#  ['국격',
#   '개판',
#   '프랑스',
#   '르몽드',
#   '기사',
#   '윤석열',
#   '배우자',
#   '김건희',
#   '뇌물',
#   '받다',
#   '금전',
#   '횡령',
#   '알려지다',
#   '현재',
#   '조사',
#   '중인',
#   '알려지다',
#   '도이치',
#   '모터',
#   '주가조작',
#   '보이다',
#   '또한',
#   '그녀',
#   '그녀',
#   '학생',
#   '이다',
#   '콜걸',
#   '활동',
#   '무당',
#   '과의',
#   '관계',
#   '대한',
#   '지속',
#   '소문',
#   '대상',
#   '이다',
#   '허위',
#   '학력',
#   '구설수',
#   '오르내리다',
#   '국내',
#   '보도',
#   '없다',
#   '외신',
#   '보도',
#   '대만',
#   '신문',
#   '성형',
#   '미인',
#   '콜걸',
#   '소문',
#   '학력',
#   '위조',
#   '국내',
#   '언론',
#   '보다',
#   '자세하다',
#   '보도',
#   '찌라시',
#   '연예인',
#   '미모',
#   '갖추다',
#   '보도',
#   '호도'],
#  ['카카오',
#   '주주',
#   '로써',
#   '글로벌',
#   '시장',
#   '테슬라',
#   '머스크',
#   '리스크',
#   '출렁이다',
#   '심하다',
#   '알파벳',
#   '넷플릭스',
#   '바닥',
#   '짚다',
#   '돌다',
#   '무조건',
#   '일선',
#   '헤딩',
#   '이니',
#   '그때',
#   '까진',
#   '참다',
#   '단타',
#   '거기',
#   '보고',
#   '있다',
#   '그래도',
#   '분전',
#   '주주',
#   '놓다',
#   '주가',
#   '원래',
#   '만원',
#   '훨씬',
#   '넘다',
#   '주가',
#   '이다',
#   '충분하다',
#   '버티다',
#   '있다',
# ...
#   '이기주의',
#   '주다',
#   '않다',
#   '통화스왑',
#   '체결',
#   '되다',
#   '계속',
#   '살펴보다',
#   '바란',
#   '다단',
#   '하락',
#   '이유',
#   '원유',
#   '버스',
#   '투자',
#   '개인',
#   '눈물',
#   '나다',
#   '주식',
#   '종목',
#   '투자',
#   '단지',
#   '하락',
#   '이유',
#   '매수',
#   '경고',
#   '로써',
#   '유비',
#   '환의',
#   '심정',
#   '대비',
#   '라는',
#   '이니',
#   '오해',
#   '없다',
#   '바라다'],
#  ['악질',
#   '이대',
#   '로기',
#   '아가리',
#   '이개',
#   '단어',
#   '단어',
#   '대한',
#   '정리',
#   '제대로',
#   '되어다',
#   '않다',
#   '인생',
#   '을사',
#   '아니다',
#   '부역',
#   '하고',
#   '있다',
#   '스터',
#   '눈뜨다'],
#  ['차다', '더럽다', '더럽다'],
#  ['개인', '개인', '많이', '가지', '있다', '무거워', '가요'],
#  ['카카오', '이다', '카카오', '명과', '같이', '소통', '하고', '있다'],
#  ['빨리', '빨리', '올라가다', '어차피', '올라가다', '빨리', '빨리', '올라가다'],
#  ['드라마', '장면', '생각나다', '지랄', '하고', '자빠지다', '라는', '장면'],
#  ['카카오',
#   '카카',
#   '페이',
#   '모든',
#   '범수',
#   '에게',
#   '책임',
#   '있다',
#   '코털',
#   '새끼',
#   '하나',
#   '여러',
#   '사람',
#   '피곤하다'],
#  ['크다', '아아', '아아', '아아', '어어', '어어', 'ㅋㅋㅋ', '아가리', '쪼오옥', '아리'],
#  ['개미', '들다', '그만', '사다'],
#  ['만원', '이면', '비싸다', '적정', '보다', '솔직하다', '만도', '비싸다', '찌다', '놓다'],
#  ['카카오', '페이', '계속'],
#  ['키우다', '상위', '이건', '나가다'],
#  ['기만', '치다', '골로', '가다', '카카오', '파이팅'],
#  ['손절', '안티', '다망', '해보다'],
#  ['껍데기', '껍데기', '신나다', '노랗다', '씹다', '보다', 'ㅎㅎ'],
#  ['회사', '문제', '아니다', '코털', '문제', '인가요'],
#  ['적정', '주가', '만원'],
#  ['끝나다', '빨리', '들다', '튀어'],
#  ['인생', '장문', '사연', '써다'],
#  ['에이', '총알', '있다', '매수', '인데', '어쩌면', '좋다', '마이너스', '도시', '마이너스'],
#  ['끝없다', '관성', '경의', 'ㅎㅎ'],
#  ['개미',
#   '털다',
#   '끝나다',
#   '음으로',
#   '올라가다',
#   '허구',
#   '시끄럽다',
#   '조용하다',
#   '있다',
#   '되다',
#   '올라가다',
#   '올라가다',
#   '이상',
#   '떨어지다',
#   '낭떠러지',
#   '낭떠러지',
#   '빨리',
#   '올라가다'],
#  ['핵실험', '버튼', '누르다', '바로', '이네', 'ㅇㅇ'],
#  ['반토막',
#   '카카오',
#   '범수',
#   '대표',
#   '당장',
#   '나오다',
#   '주가',
#   '부양',
#   '다시',
#   '짜다',
#   '주주',
#   '치다',
#   '먹다',
#   '너희',
#   '자다',
#   '안되다'],
#  ['호호', '들이다', '카를', '믿다', '손각락', '원망하다'],
#  ['크다', '가다'],
#  ['이런',
#   '악질',
#   '기업',
#   '사라지다',
#   '깨끗해지다',
#   '언제',
#   '천벌',
#   '받다',
#   '망하다',
#   '대가리',
#   '넘다',
#   '들다'],
#  ['지선', '이탈'],
#  ['코스피',
#   '암세포',
#   '계열',
#   '사상',
#   '팔이',
#   '지뢰',
#   '깔다',
#   '놓다',
#   '개미',
#   '박멸',
#   'ㅋㅋㅋㅋㅋ',
#   '장하다',
#   '범수',
#   '코스피',
#   '에서나',
#   '가능하다',
#   '합법',
#   '코스프레',
#   '범죄'],
#  ['생각', '보다', '빠지다', 'ㅎㅎ', '카카오', '페이', '보호', '물량', '풀다', '빠지다', '알다'],
#  ['오늘', '찌다', '바닥', '만들다', '매수', '해도', '되다'],
#  ['카카오', '페이', '주주', '만주', '던지다', '카카오', '페이', '년월', '주가', '재주', '만원', '하하'],
#  ['문재인', '마넌', '에서', '마넌', '가다', '윤석열', '올리겐', 'ㅋㅋㅋ'],
#  ['드디어', '다자'],
#  ['쫄리'],
#  ['카카오', '차다', '가지가지', '회사', '맞다'],
#  ['카카오', '가다', '만원'],
#  ['오늘', '긋다', 'ㅋㅋㅋㅋㅋㅋㅋ', '연기금', '들다', '월동', '던지다', 'ㅋㅋㅋ', '오르다', '누르다', 'ㅋㅋㅋ'],
#  ['카카오',
#   '솔직하다',
#   '분할',
#   '체제',
#   '가다',
#   '도대체',
#   '상장',
#   '몇개',
#   '애플',
#   '보다',
#   '하나로',
#   '가다',
#   '가치',
#   '상승'],
#  ['찌다', '찌다', '찌다', '오늘', '찌다', '바닥'],
#  ['보다', '가지', '않다'],
#  ['역시',
#   '크다',
#   '쓰레기',
#   '이렇다',
#   '쓰레기',
#   '상장',
#   '만원',
#   '어쩌',
#   '저쩌',
#   '보다',
#   '낙지',
#   '대가리',
#   '꼬챙이',
#   '팍팍',
#   '쑤시다',
#   '버리다',
#   '싶다'],
#  ['밉다',
#   '개관',
#   '어제',
#   '공매',
#   '겁나다',
#   '치다',
#   '오늘',
#   '올리다',
#   '공매',
#   '치다',
#   '밀다',
#   '에이',
#   '더러',
#   '공매'],
#  ['폭포수', '계좌', '녹아내리다', 'ㅎㅎ'],
#  ['거의', '오다', '조금', '힘내다'],
#  ['카카오', '시대', '예견', '돼다'],
#  ['신저', '갱신', '하자'],
#  ['그렇게', '가져가다', '속이다', '후련하다'],
#  ['카카오', '만원', '정말', '인가', '이제', '만원', '넘기다', '힘들다', '조심'],
#  ['여덟', '번째', '물어보다', '평단', '만원', '마르다', '만원', '깨다', '같다'],
#  ['유영', '손절손절', '유영'],
#  ['진짜', '갈수', '있다', '다머', '회사', '신뢰', '가다'],
#  ['쓰레기', '계속', '공매', '치다', '라다', '사주다', '망하다'],
#  ['망하다', 'ㅋㅋㅇ'],
#  ['차다',
#   '불쌍하다',
#   '앵두',
#   '믿다',
#   '사람',
#   '옛말',
#   '듣다',
#   '주식',
#   '대가',
#   '망하다',
#   '햇음',
#   'ㅋㅋㅋ',
#   '작년',
#   '모든',
#   '주식',
#   '이오',
#   '어떤',
#   '주식',
#   '사도',
#   '랏음',
#   '그냥',
#   '앵두',
#   '아니다',
#   '다른',
#   '앵두',
#   '라도',
#   '근데',
#   '금은',
#   '하락',
#   '에서',
#   '정확도',
#   '아예',
#   '맞다',
#   '않다',
#   'ㅋㅋㅋㅋㅋㅋ'],
#  ['꺾다', '초반', '까지', '열다', '두다', '경영', '가부', '양의지', '없다', '악재', '그득하다'],
#  ['익절', '평단', '만천', '인데', '익절', '이다'],
#  ['삼성', '머스트', '스팩', '삼성'],
#  ['크다', '그룹', '사기꾼', '그룹', '이렇다', '쓰레기', '상장', '시키다', '대한민국', '미치다'],
#  ['오늘', '치다', '보나', '네이버', '카카오', '팍팍'],
#  ['진짜', '개케오', '너무하다', '뭐라다', '해보다', '자꾸', '쪼개다', '생각', '만하', '말고'],
#  ['네이버', '홈페이지', '유명하다', '카카오', '홈페이지'],
#  ['끄다', '까오', '완전', '돼다', 'ㅋㅋㅋ'],
#  ['매수', '걸다', '아이구', 'ㅎㅎㅎ', '제발', '통과', '되다', 'ㄱㄱㄱㄱ'],
#  ['국민', '민페주', '국민', '잡다', '이렇게', '처참하다', '작살', '내다'],
#  ['주가', '관리'],
#  ['깨지다', '거품', '기업'],
#  ['잣두', '뒤지다', 'ㅡㅡ'],
#  ['ㅎㅎ',
#   '어디',
#   '매수',
#   '들어오다',
#   '그리고',
#   '간다',
#   '여기',
#   '적지',
#   '말고',
#   '공매도',
#   '치다',
#   '많이',
#   '벌다',
#   '같다',
#   'ㅎㅎ',
#   '어서',
#   '공매도',
#   '치다',
#   '재산',
#   '걸다',
#   '시오니',
#   '개쫄리',
#   '구간',
#   '인거',
#   '모르다',
#   '같다',
#   'ㅋㅋ'],
#  ['개미',
#   '죽이다',
#   '가다',
#   '그냥',
#   '가치',
#   '없다',
#   '팔다',
#   '임차',
#   '전지',
#   '주도',
#   '주임',
#   '오늘',
#   '같다',
#   '빨강',
#   '불임'],
#  ['카카오',
#   '추가',
#   '상장',
#   '어이없다',
#   '회사',
#   '카카오',
#   '보통주',
#   '추가',
#   '상장',
#   '주식',
#   '종류',
#   '보통주',
#   '주의',
#   '발행',
#   '가액',
#   '원주',
#   '원주',
#   '원주',
#   '원주',
#   '원주',
#   '원주',
#   '원주',
#   '원주',
#   '발행',
#   '년월',
#   '배당',
#   '산일',
#   '년월',
#   '결산',
#   '일월',
#   '말일',
#   '증자',
#   '방법',
#   '스톡옵션',
#   '행사',
#   '상장',
#   '년월',
#   '코드',
#   '보통주',
#   '표준',
#   '코드',
#   '단축',
#   '코드',
#   '업종',
#   '코드'],
#  ['만원', '까지는', '촉수', '금물', '만원', '매수'],
#  ['주식',
#   '만원',
#   '되다',
#   '까지',
#   '이렇게',
#   '근무',
#   '아니다',
#   '되다',
#   '제발',
#   '한편',
#   '카카오',
#   '무제',
#   '수정',
#   '안과',
#   '함께',
#   '놀금',
#   '출근',
#   '않다',
#   '금요일',
#   '제도',
#   '격주',
#   '도입',
#   '검토',
#   '중인',
#   '알려지다',
#   '놀금',
#   '제도',
#   '도입',
#   '되다',
#   '수정',
#   '되다',
#   '메타',
#   '버스',
#   '무제',
#   '함께',
#   '오다',
#   '부터',
#   '적용',
#   '되다',
#   '보이다',
#   '주식',
#   '제자리',
#   '갖다',
#   '놓다',
#   '놀다',
#   '아니다',
#   '직원',
#   '프로',
#   '정리',
#   '제발'],
#  ['주식',
#   '대여',
#   '은상',
#   '가다',
#   '매도',
#   '주문',
#   '걸다',
#   '쓰다',
#   '팔리다',
#   '좋다',
#   '팔다',
#   '주가',
#   '방어',
#   '되다'],
#  ['배당금', '웃끼', '일년', '만에', '들어오다', '배당금', '대박'],
#  ['유튜브', '에서', '추천', '박다', '반등', '개뿔', '새끼', '치다'],
#  ['보유',
#   '카카오',
#   '바닥',
#   '나오다',
#   '유대',
#   '자본',
#   '이상',
#   '미국',
#   '하락',
#   '원하다',
#   '않다',
#   '바닥',
#   '확인',
#   '이제',
#   '부터',
#   '폭등',
#   '미국',
#   '주식',
#   '카카오',
#   '날아가다'],
#  ['만원',
#   '대가',
#   '보이다',
#   '연말',
#   '까지',
#   '기다리다',
#   '만원',
#   '가다',
#   '물론',
#   '가격',
#   '바닥',
#   '아니다',
#   '같다',
#   '지금',
#   '던지다'],
#  ['유영', '가원', '인가', '지지', '되다', '늘다', 'ㅋㅋㅋ', '얼마', '라고', '우길'],
#  ['하고', '있다', '유가', '쭈욱', '공행', '진정', '유주', '갈아타다'],
#  ['칠만', '카카오', 'ㅋㅋㅋㅋ', '죽겠네'],
#  ['쉐키',
#   '드루',
#   '드루',
#   '개미',
#   '뭉치',
#   '그게',
#   '세력',
#   '이야',
#   '상한',
#   '매도',
#   '운동',
#   '동참',
#   '해주다'],
#  ['조만간', '카카오', '기다리다'],
#  ['내일', '놀금', '이야'],
#  ['ㅋㅋ',
#   '웃다',
#   '가다',
#   '사장',
#   '세리',
#   '상장',
#   '자마자',
#   '먹다',
#   '한개',
#   '회사',
#   '이상',
#   '나누다',
#   '주식',
#   '사하다',
#   '회사',
#   '인데',
#   '가도',
#   '엄청',
#   '비싸다',
#   '아니다',
#   '회사',
#   '계산법',
#   '삼성',
#   '나누다',
#   '되다',
#   '정도'],
#  ['완전', '차반', '주식', '되어다'],
#  ['오다', '넘다', '솔직하다', '오다', '아니다', '같이', '죽다', 'ㅋㅋㅋㅋ'],
#  ['네이버',
#   '양호',
#   '네이버',
#   '보다',
#   '추풍낙엽',
#   '이다',
#   '거의',
#   '망하다',
#   '수준',
#   '추락',
#   '이다',
#   'ㅋㅋㅋ'],
#  ['크다', '망하다', '되다'],
#  ['카카오', '문재인', '테마주', '이제', '알다'],
#  ['주가',
#   '오르다',
#   '어느',
#   '정도',
#   '오르다',
#   '분할',
#   '먹다',
#   '앉다',
#   '당하',
#   '긋다',
#   '이런',
#   '회사',
#   '투자',
#   '가치',
#   '없다',
#   '그냥',
#   '타용'],
#  ['아직',
#   '멀다',
#   '따다',
#   '카카오',
#   '쇼핑',
#   '카카오',
#   '모빌리티',
#   '카카오',
#   '웹툰',
#   '카카오',
#   '얼른',
#   '상장',
#   '제대로',
#   '하나',
#   '없다',
#   '아직',
#   '조금',
#   '이라도',
#   '남다',
#   '주식',
#   '하나',
#   '라도',
#   '먹다',
#   '튀다',
#   '영진',
#   '돌대가리'],
#  ['이렇다', '쓰레기', '회사', '금융', '허가', '되다', '문빠', '책임지다', '상복', '구해'],
#  ['그냥', '폐업', '따위', '무슨', '상장', '사다'],
#  ['토나오다', '잡다'],
#  ['개미',
#   '고기',
#   '방패',
#   '오지',
#   'ㅋㅋㅋ',
#   '만오',
#   '매수',
#   '유효',
#   '스윙',
#   '개미',
#   '시체',
#   '씹다',
#   '오다',
#   'ㅋㅋㅋ'],
#  ['크다', '가다', '화끈하다'],
#  ['ㅎㅎ',
#   '여기',
#   '내다',
#   '적다',
#   '공매',
#   '쫄려',
#   '치다',
#   '어디가',
#   '악플달다',
#   '관심',
#   '가다',
#   '좋다',
#   '그렇다',
#   '공매',
#   '치다',
#   '마음껏',
#   '진심',
#   '공매',
#   '신용',
#   '미수',
#   '풀배팅',
#   '그렇게',
#   '내다',
#   '식이',
#   '그저',
#   '어떻',
#   '싸다',
#   '사다',
#   '안달',
#   '이네',
#   '지금',
#   '살리다',
#   'ㅎㅎ',
#   '떨어지다',
#   '사다',
#   '지도',
#   '팔지',
#   '주둥이',
#   '살다',
#   '팔딱대다',
#   '라지',
#   '역겹다',
#   'ㅎㅎ'],
#  ['드디어', '보다'],
#  ['탈출', '지능'],
#  ['공매',
#   '한테',
#   '한마디',
#   '해주다',
#   '공매',
#   '최대로',
#   '먹다',
#   '보다',
#   '프로',
#   '손실',
#   '무한대',
#   '치다',
#   '조용하다',
#   '찌그러지다',
#   '가다',
#   '먹다',
#   '끄다',
#   '알다'],
#  ['매수', '금지', '종목', '크다', '차트', '보다'],
#  ['이번', '까지야'],
#  ['언제', '까지', '치다'],
#  ['지난번', '에서', '타다', '까지', '물탄', '금욜', '빠져나오다', '이리', '편하다'],
#  ['버리다', '타이타닉', '침몰'],
#  ['먹다', '카카오', '만원', '가다', 'ㅡㅡ'],
#  ['봉상', '일선', '기다'],
#  ['대기'],
#  ['생각',
#   '해보다',
#   '너무',
#   '무겁다',
#   '이상',
#   '플랫폼',
#   '전부',
#   '열사',
#   '빠져나가다',
#   '있다',
#   '따르다',
#   '지주',
#   '감소',
#   '요건',
#   '전부',
#   '갖다',
#   '차다',
#   '엔시',
#   '소프트',
#   '주가',
#   '따라가다'],
#  ['박자', '자다', '맞다', '개관', '외인', '프로그램', '치다', '팔고', '있다', '차다', '자다', '이다'],
#  ['제도',
#   '특혜',
#   '국내',
#   '독점',
#   '다가',
#   '제조',
#   '특혜',
#   '안주',
#   '니까',
#   '바로',
#   '좌파',
#   '그렇게',
#   '핥다',
#   '대가',
#   '치르다'],
#  ['여기', '만이', '지선', '이라', '생각', '사람', '없다'],
#  ['커버', '들어오다'],
#  ['이제',
#   '만원',
#   '에서',
#   '오래',
#   '머무르다',
#   '이제',
#   '카카오',
#   '가야',
#   '되다',
#   '이다',
#   '모두',
#   '돔황챠',
#   '만원',
#   '한다는',
#   '흑우',
#   '없다'],
#  ['여기', '공매도', '어쩔', '매도', '고고씽', '공매도', '박멸'],
#  ['막판', '폭락', '예감'],
#  ['평단', '강가', '쉬바', '프로', '먹다', '같다', '주식'],
#  ['여기', '주식', '질문', '신규', '진입', '적정', '얼마', '인가요'],
#  ['진짜', '너무하다', '주거', '삐라'],
#  ['쪼개다', '먹다', '없다', '두리', '두리'],
#  ['기미', '그냥', '폐시', '언제', '까지', '빼다', '사주', '매입', '손실', '보충', '무증좀', '하자'],
#  ['염블',
#   '리가',
#   '얼마',
#   '카카오',
#   '사라',
#   '추하다',
#   'ㅋㅋㅋㅋ',
#   '그때',
#   '가격',
#   '만원',
#   '중반',
#   '이다',
#   '염블리',
#   '정말',
#   '모든',
#   '종목',
#   '좋다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['종목',
#   '추천',
#   '드리다',
#   '셀트리온',
#   '한미',
#   '약품',
#   '유니',
#   '퀘스트',
#   '라서',
#   '이상',
#   '투자',
#   '최소',
#   '이상',
#   '수익',
#   '다년',
#   '경력'],
#  ['크다', '깨지다', '팔카오', '슈팅', '날다'],
#  ['배당금', '올려주다', '너무', '짜다'],
#  ['배당금',
#   '올려주다',
#   '주주',
#   '원성',
#   '자자하다',
#   '내년',
#   '범수',
#   '크다',
#   '먹다',
#   '배당',
#   '프로',
#   '인상',
#   '요원'],
#  ['개미',
#   '수급',
#   '보다',
#   'ㅋㅋ',
#   '실화',
#   'ㅋㅋㅋ',
#   '반토막',
#   '나다',
#   '정신',
#   '차리다',
#   '공매도',
#   '폭탄',
#   '맛좀',
#   '보다',
#   '정신차리다'],
#  ['공포', '매수'],
#  ['카뱅', '요즘', '강하다', '카카오', '신저', '부근'],
#  ['풍악', '울리다', '조금', '오다', '닐리리', '리리', '나노', '배신', '알제'],
#  ['앵두',
#   '먹다',
#   '다니다',
#   '유튜브',
#   '앵벌이',
#   'ㅋㅋ',
#   '유대',
#   '금융',
#   'ㅋㅋ',
#   '에는',
#   '앵두',
#   '허경영',
#   '이다',
#   'ㅋㅋ'],
#  ['까지', '내려가다', '어느', '정도', '자기', '자리', '찾다'],
#  ['전라도', '전라도'],
#  ['카카오',
#   '만원',
#   '가야',
#   '적정',
#   '분할',
#   '넘다',
#   '쓰다',
#   'ㅋㅋ',
#   '페이',
#   '게임',
#   '뱅크',
#   '분리',
#   '주가',
#   '만원',
#   '이냐',
#   'ㅡㅡㅋㅋ'],
#  ['공매도',
#   '리스크',
#   '전쟁',
#   '나야',
#   '카카오',
#   '원상',
#   '복구',
#   '되다',
#   '부자',
#   '되다',
#   '아니다',
#   '스므살',
#   '되다',
#   '아니다',
#   '멘탈',
#   '봉괴',
#   '되어다'],
#  ['전자', '카카오', '폭망', '개미', '전략', '존버', '타다'],
#  ['카뱅', '급등', '이네', '차다'],
#  ['이다',
#   '버티다',
#   '전량',
#   '모두',
#   '매도',
#   '자다',
#   '건지다',
#   '모르다',
#   '조금',
#   '씁쓸하다',
#   '모든',
#   '분들',
#   '투하'],
#  ['아직', '만만원', '비싸다', '만원', '정선'],
#  ['종가', '예상', '모두', '내다'],
#  ['남궁훈',
#   '대표이사',
#   '갑부',
#   '이다',
#   '비다',
#   '최고',
#   '주식',
#   '부자',
#   '국내',
#   '대기업',
#   '에서',
#   '축하',
#   '축하'],
#  ['양봉', '마감'],
#  ['만해',
#   '카카오',
#   '떨어지다',
#   '사람',
#   '많다',
#   '공매도',
#   '치다',
#   '금은',
#   '오전',
#   '보다',
#   '높아지다',
#   '공매도',
#   '사람',
#   '공매도',
#   '많이',
#   '치다',
#   '진짜',
#   '인생',
#   '나락',
#   '갈다',
#   '있다',
#   '거래',
#   '많다',
#   '주식',
#   '함부로',
#   '공매',
#   '치다',
#   '아니다'],
#  ['진작', '전액', '절하', '자다', '사주', '분할', '계속', '버티다', '의미', '있다'],
#  ['아직', '바닥', '니지', '훼이크'],
#  ['드랏',
#   '하노',
#   '죽다',
#   '불알',
#   '따따',
#   '치다',
#   '빨닥스길',
#   '팔만',
#   '아프다',
#   '아이',
#   '잡다',
#   '버리다',
#   '되다',
#   '종목',
#   '사르다',
#   '쌍용차',
#   '조차'],
#  ['직원',
#   '일도',
#   '회사',
#   'ㅋㅋㅋㅋ',
#   '다음',
#   '사서',
#   '최고점',
#   '파다',
#   '먹음',
#   'ㅋㅋㅋㅋ',
#   '오랜',
#   '오다',
#   '보다',
#   '개그',
#   '이네',
#   '분전',
#   '이다'],
#  ['증시',
#   '그만',
#   '떨어지다',
#   '좋다',
#   '증시',
#   '그만',
#   '떨어지다',
#   '좋다',
#   '너무',
#   '힘들다',
#   'ㅜㅜ',
#   '만월',
#   '옵션',
#   '만기일',
#   '이후',
#   '반등'],
#  ['평단', '가망', '없다', '어느덧다', '이다', '본전', '이라도', '갈수', '없다'],
#  ['남다', '얼른얼른', '힘내다', '가다'],
#  ['잡다', '끝나다', 'ㅋㅋㅋㅋ'],
#  ['시작', '튀어'],
#  ['내내', '치다', '있다', '주주', '내내', '치다', '맞다', '있다', '범수', '대표', '이오나'],
#  ['목표', '예상', '물론', '년안'],
#  ['발암', '주식', '매수', '순간', '탈모', '신경', '쇠약', '우울증', '수명', '단축', '개털', '크다'],
#  ['ㅋㅋ',
#   '카카오',
#   '아직',
#   '바닥',
#   '다지다',
#   '멀다',
#   '요만',
#   '초반',
#   '에서',
#   '다시',
#   '타다',
#   '개미',
#   '주주',
#   '만들기'],
#  ['분할', '아직도', '만원', '비싸다', '비싸다', '원가', '되다'],
#  ['카카오', '글내', '빨다', '연봉', '올리다', '좋니존버', '연봉', '올리다', '만큼', '주식', '올리다'],
#  ['ㅎㅎ', '기관', '삼전', '양전'],
#  ['오늘', '매수', '신분', 'ㅊㅊㅊㅊ', '매수'],
#  ['마녀', '마물', '어케', '변동성', '크다', '들다', '눈치', '작전', 'ㅋㅋㅋ'],
#  ['언제', '오르다', '유유', '오르다'],
#  ['오늘', '타다', '이상'],
#  ['크다', '갈다', '쎄다', '벌리다', '써다', 'ㅋㅋ', '야레야레'],
#  ['꼬리', '달구', '양봉'],
#  ['금투', '젓다', '매수'],
#  ['시간', '폭등', '이네', 'ㄷㄷㄷ', '있다', 'ㄷㄷㄷ', '내일', '만원', '찍다', 'ㄷㄷㄷ'],
#  ['개미',
#   '그냥',
#   '가지',
#   '있다',
#   '사고팔다',
#   '육갑',
#   '떨다',
#   '말고',
#   '그냥',
#   '진득',
#   '허니',
#   '가지',
#   '있다'],
#  ['종가', '대량', '거래', '뭔가', 'ㅎㄷㄷ', '만주'],
#  ['부근', '긁다', '사이', '산다', 'ㅇㅋ'],
#  ['두산',
#   '밥캣',
#   '분기',
#   '배당',
#   '주다',
#   '만원',
#   '짜다',
#   '리가',
#   '배당',
#   '주니',
#   '주식',
#   '수만',
#   '많다',
#   'ㅉㅉㅉㅉ'],
#  ['밉다', '선물', '상승', '전환'],
#  ['내내', '내리다', '충분하다', '플랫폼', '반토막', '내다', '나라', '중국', '하고', '한국', '이다'],
#  ['안티',
#   '오늘',
#   '매수',
#   '해보다',
#   '명일',
#   '하락',
#   '되다',
#   '추가',
#   '매수',
#   '예정',
#   '적정',
#   '매수',
#   '고수'],
#  ['내일', '추가', '상장', '있다', 'ㅡㅡ'],
#  ['배당', '보다', 'ㅎㅎ', '이주'],
#  ['ㅋㅋ',
#   '확실하다',
#   '카카오',
#   '붙다',
#   '투자',
#   '내부',
#   '사업',
#   '커지다',
#   '분할',
#   '함카겜',
#   '에서',
#   '분하다',
#   '갈수록',
#   '쓰레기',
#   '내년',
#   '카카오',
#   '짜다',
#   '보다'],
#  ['좋다', '굿바이', '사요나라'],
#  ['내일', '추가', '상장', '대기', '치다', '있다'],
#  ['만원', '이하', '오다', '바로', '정찰', '투입', '까진', '절대', '안해'],
#  ['이렇다', '잡다', '아직', '들다', '얼른', '털다', '노터스로'],
#  ['꺼지다',
#   '이카루스',
#   '후예',
#   '날개',
#   '녹다',
#   '추락',
#   '죽다',
#   '이카루스',
#   '복날',
#   '내다',
#   '녹다',
#   '없어지다',
#   '도난',
#   '카카오',
#   '함께',
#   '최후',
#   '맞다',
#   '주주',
#   '아니다',
#   '멀다',
#   '들다',
#   '닥치고',
#   '끄다'],
#  ['대차', '거래', '잔고', '상환', '상위', '종목'],
#  ['크다',
#   '내년',
#   '배당',
#   '주다',
#   'ㅋㅋ',
#   '주가',
#   '반토막',
#   '나다',
#   '역시',
#   '임원',
#   '떼다',
#   '터지다',
#   '먹다',
#   '크다',
#   '많이',
#   '들다',
#   '사라',
#   '단타',
#   '딱이다'],
#  ['로보',
#   '로봇',
#   '코딩',
#   '메타',
#   '버스',
#   '윤통',
#   '보로',
#   '로봇',
#   '만들다',
#   '먼저',
#   '교육',
#   '중요윤통',
#   '이제',
#   '보로',
#   '보가',
#   '대세',
#   '동호회',
#   '광고',
#   '아니다',
#   '보로',
#   '회사',
#   '에서',
#   '직접',
#   '제작',
#   '짜다',
#   '소개',
#   '동영상',
#   '이에요',
#   '시간',
#   '아깝다',
#   '않다',
#   '한번',
#   '보다',
#   '보다',
#   '그리고',
#   '총리',
#   '인재',
#   '키우다'],
#  ['보유', '평단', '원주'],
#  ['만원', '물리다', '친구', '많다'],
#  ['잡다', '배당', '나오다', '냉무'],
#  ['크다',
#   '플랫폼',
#   '기업',
#   '광고',
#   '이커머스',
#   '수입',
#   '인데',
#   '경기',
#   '침체',
#   '광고',
#   '삭감',
#   '근데',
#   '분할',
#   '까지',
#   '대기',
#   '하고',
#   '있다',
#   '만원',
#   '에서',
#   '만나다'],
#  ['카카오',
#   '누누',
#   '지만',
#   '정치',
#   '테마',
#   '주임',
#   '민주당',
#   '열심히',
#   '빨다',
#   '제도',
#   '통과',
#   '켜다',
#   '특정시',
#   '장악',
#   '카카오',
#   '혁신',
#   '이자',
#   '성장',
#   '이다',
#   '근데',
#   '정권',
#   '바뀌다',
#   '그렇다',
#   '먹히다',
#   '리가',
#   '없다',
#   'ㅋㅋ',
#   '아주',
#   '온갖',
#   '생활',
#   '깊숙하다',
#   '카카오',
#   '국민',
#   '지배',
#   '같이',
#   '실패',
#   'ㅋㅋㅋㅋㅋ',
#   '잊다',
#   '민주당',
#   '정권',
#   '오기',
#   '직전',
#   '카카오',
#   '사고',
#   '민주당',
#   '정권',
#   '뺏다',
#   '같다',
#   '아야'],
#  ['카카오',
#   '그룹',
#   '투자',
#   '금지',
#   '꼬락서니',
#   '보다',
#   '조만간',
#   '뱅크',
#   '게임',
#   '블록딜',
#   '시전',
#   '예상',
#   '최태원',
#   '상장',
#   '회사',
#   '블록딜',
#   '년안',
#   '개함',
#   '참고',
#   '하고',
#   '상장',
#   '임원',
#   '초기',
#   '따리',
#   '스톡',
#   '수백',
#   '만주',
#   '먹다',
#   '넘다',
#   '들다',
#   '돈번',
#   '여기다',
#   '끝나다',
#   '신뢰',
#   '잃다',
#   '아작이다',
#   '난거지',
#   '계속',
#   '넣다',
#   '보다',
#   'ㅋㅋㅋ',
#   '살길',
#   '임원',
#   '직원',
#   '우리나라',
#   '에서',
#   '최고',
#   '연봉',
#   '넘다',
#   '들이다',
#   '좀덜',
#   '먹다',
#   '주주',
#   '에게',
#   '환원',
#   '스톡옵션',
#   '그만',
#   '각하',
#   '만큼',
#   '보다',
#   '많이',
#   '주식',
#   '수가',
#   '생겨나다',
#   'ㅋㅋ',
#   '완전',
#   '복사기',
#   'ㅋㅋㅋㅋㅋ',
#   '미치다',
#   '창조경제',
#   'ㅋㅋㅋ',
#   '하루빨리',
#   '신뢰',
#   '얻다',
#   '돌리다',
#   '늦다',
#   '옵션',
#   '중단',
#   '상장',
#   '중단',
#   '버는거',
#   '절반',
#   '소각',
#   '배당',
#   '주다',
#   '만원',
#   '뿌리다',
#   'ㅋㅋ',
#   '그래도',
#   '희망이',
#   '보이다',
#   '끄다',
#   '믿다',
#   'ㅋㅋ',
#   '과연',
#   '되다',
#   '절대',
#   '힘들다',
#   '한번',
#   '상장',
#   '몇십',
#   '조가',
#   '주머니',
#   '들어오다',
#   '포기',
#   '나라',
#   '안함',
#   'ㅋㅋ',
#   '이건',
#   '나라',
#   '들다',
#   '막다',
#   '있다',
#   '사람',
#   '살다',
#   '말고는'],
#  ['진짜',
#   '상공',
#   '피빨',
#   '먹다',
#   '기업',
#   '상생',
#   '개뿔',
#   'ㅋㅋㅋㅋ',
#   '카카오',
#   '너무',
#   '많다',
#   '그렇다',
#   '적당하다',
#   '해처',
#   '먹다',
#   'ㅋㅋㅋㅋ',
#   '문어',
#   '줄이다',
#   '늘리다',
#   'ㅋㅋㅋㅋㅋㅋㅋ',
#   '사업',
#   '꾸역꾸역',
#   '늘리다',
#   '상장',
#   '시키다',
#   '벌다',
#   '야하다',
#   'ㅋㅋㅋ',
#   '사업',
#   '으론',
#   '벌다'],
#  ['색안경',
#   '끼다',
#   '보다',
#   '없다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '좋다',
#   '하나',
#   '라도',
#   '있다',
#   '골목',
#   '상권',
#   '리스크',
#   '거머리',
#   'ㄲㅈ',
#   '해외',
#   '시장',
#   '레드',
#   '오션',
#   '오픈',
#   '채팅',
#   '우린',
#   '짱짱맨',
#   '작전',
#   '라지',
#   'ㅋㅋㅋㅋㅋㅋㅋ',
#   '응안써범슈',
#   '카카',
#   '오카',
#   '카페',
#   '미치다',
#   '버리다',
#   '정권',
#   '교체',
#   '나락',
#   '지금',
#   '그리고',
#   '세계',
#   '시장',
#   '기술',
#   '지옥',
#   '분기',
#   '매출',
#   '역성',
#   '장주주',
#   '진짜',
#   '썩다',
#   '빨리',
#   '털다',
#   '구글',
#   '같다',
#   '사라',
#   '년전',
#   '부터',
#   '아직도',
#   '들다'],
#  ...]

# %%
print('리뷰의 최대 길이 :',max(len(review) for review in tokenized_data))
print('리뷰의 평균 길이 :',sum(map(len, tokenized_data))/len(tokenized_data))
plt.hist([len(review) for review in tokenized_data], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 707
# 리뷰의 평균 길이 : 18.415558912386707

# %%
from gensim.models import Word2Vec

model = Word2Vec(sentences = tokenized_data, vector_size = 100, window = 5, min_count = 5, workers = 4, sg = 0)

# %%
# 완성된 임베딩 매트릭스의 크기 확인
model.wv.vectors.shape
# Out:
# (3498, 100)

# %%
#print(model.wv.most_similar("카카오"))
sw = model.wv.most_similar("카카오")
sw
# Out:
# [('뱅크', 0.9960635900497437),
#  ('페이', 0.9946475625038147),
#  ('게임', 0.9935821890830994),
#  ('분할', 0.9924075603485107),
#  ('모빌리티', 0.9923713207244873),
#  ('매각', 0.990277111530304),
#  ('토막', 0.9901171922683716),
#  ('적정', 0.989971399307251),
#  ('쪼개다', 0.9899539947509766),
#  ('열사', 0.9896731972694397)]

# %%
model.wv.most_similar("김범수")
# Out:
# [('먹튀', 0.9995537400245667),
#  ('대표', 0.9994967579841614),
#  ('문어', 0.9994566440582275),
#  ('문재인', 0.9994105100631714),
#  ('범수', 0.999410092830658),
#  ('국민', 0.9993857741355896),
#  ('플랫폼', 0.9993365406990051),
#  ('전부', 0.999334990978241),
#  ('쓰다', 0.9993262887001038),
#  ('이익', 0.9993171691894531)]
