# %%
import pandas as pd

b = pd.read_table('/Users/ijunhui/Downloads/ubion/해커톤/SentiWord_Dict.txt')
b
# Out:
#           단어  점수
# 0        (-;   1
# 1      (;_;)  -1
# 2       (^^)   1
# 3      (^-^)   1
# 4       (^^*   1
# ...      ...  ..
# 14850    갈등   -1
# 14851     의혹  -1
# 14852  내팽개치다  -2
# 14853     횡령  -2
# 14854    불안증  -2
#
# [14855 rows x 2 columns]

# %%
a = pd.read_csv('/Users/ijunhui/Downloads/ubion/해커톤/kakao_2206.csv')
a['전체'] = a['제목'] + a['본문']
a
# Out:
#                   전체날짜  종목명                        제목  \
# 0     2022.06.01 05:23  카카오  이시간에 카카오메인이 조선이 싹쓸이하네...
# 1     2022.06.01 08:44  카카오                돈은 많이 받으면서
# 2     2022.06.01 08:59  카카오      유영두 할아버지 넘 실망이에요~~^^
# 3     2022.06.01 09:29  카카오            빡빡이 하는짓 보면 모르나
# 4     2022.06.01 09:37  카카오     한오백년 전쟁하자는 미필 양키괴뢰!!!
# ...                ...  ...                       ...
# 6615  2022.06.30 23:31  카카오       이거보고 윤석열이 왕따라고 생각하면
# 6616  2022.06.30 23:34  카카오                    잠이 안온다
# 6617  2022.06.30 23:40  카카오           이거 액분전에 평균얼마엿어요
# 6618  2022.06.30 23:52  카카오                    나스닥 7천
# 6619  2022.06.30 23:54  카카오                   카카오 계열사
#
#                                                      본문  \
# 0     메인 7개 뉴스중에 5개가 조선1개가 동아 1개가 듣보잡 인터넷언론....이러니 주...
# 1     근무시간에 오디오라인 열어놓는게 불만이라니\n그냥 집에서 누워서 tv보면서 근무하고...
# 2     토른방에 남겨진 유영두 할아버지에 대한 댓글 입니다.\n"범수 똘마니 의심 "\n"...
# 3     김범수가 일궈낸 자리 편하게 앉아서 메타버스 빌미로 날로 먹을려고 하는거지\n\n카...
# ...

# %%
a_list = a['전체']
w_list = b['단어']
def test(i, j):
    for i in a_list:
        for j in w_list:
            if j in i:
                return(j)

# %%
import torch
import torchvision

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"    # gpu 할당 in jupyter
os.environ["CUDA_VISIBLE_DEVICES"]= "4"

device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
# 입력값을 리스트로 변환

texts = list(a['전체'])
texts[:4]
# Out:
# ['이시간에 카카오메인이 조선이 싹쓸이하네...메인 7개 뉴스중에 5개가 조선1개가 동아 1개가 듣보잡 인터넷언론....이러니 주가가 이모양이지..',
#  '돈은 많이 받으면서근무시간에 오디오라인 열어놓는게 불만이라니\n그냥 집에서 누워서 tv보면서 근무하고 싶나보다. 그냥 출근 시켜라. 주가 반토막났는데도 성과급이랑 월급 인상해서 꼬박꼬박 다 처받아가면서 불만 졸라 많네',
#  '유영두 할아버지 넘 실망이에요~~^^토른방에 남겨진 유영두 할아버지에 대한 댓글 입니다.\n"범수 똘마니 의심 "\n"생긴것이 사기꾼"\n"영두 방송보면서 사기꾼인지 모르면 주식 접어라"\n이런 댓글들을 보게되면 할아버지께 너무 실망감이 큽니다.\n할아버지 이런 댓글들이 증말 사실은 아니겠지요?\n저는 할아버지만 믿어요~^^',
#  '빡빡이 하는짓 보면 모르나김범수가 일궈낸 자리 편하게 앉아서 메타버스 빌미로 날로 먹을려고 하는거지\n\n카카오 대표 빡빡이로 바뀌고나서 직원들만 배불리기만했지 개선은 되긴 했냐?']

# %%
# !pip install transformers
# Out:
# ...
#   Using cached transformers-4.21.0-py3-none-any.whl (4.7 MB)
# ...
#   Using cached regex-2022.7.25-cp39-cp39-macosx_11_0_arm64.whl (282 kB)
# ...
#   Using cached huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
# ...
#   Using cached tokenizers-0.12.1.tar.gz (220 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Traceback (most recent call last):
#         File "/opt/homebrew/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 363, in <module>
#           main()
#         File "/opt/homebrew/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 345, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
# ...

# %%
import transformers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/ijunhui/Downloads/ubion/해커톤/sentiword.ipynb 셀 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ijunhui/Downloads/ubion/%ED%95%B4%EC%BB%A4%ED%86%A4/sentiword.ipynb#ch0000009?line=0'>1</a> import transformers
#
# ModuleNotFoundError: No module named 'transformers'

# %%
# 사전학습 모델 로드
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("snunlp/KR-FinBert-SC")
model = AutoModelForSequenceClassification.from_pretrained("snunlp/KR-FinBert-SC").to(device)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/ijunhui/Downloads/ubion/해커톤/sentiword.ipynb 셀 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/ijunhui/Downloads/ubion/%ED%95%B4%EC%BB%A4%ED%86%A4/sentiword.ipynb#ch0000005?line=0'>1</a> # 사전학습 모델 로드
# ----> <a href='vscode-notebook-cell:/Users/ijunhui/Downloads/ubion/%ED%95%B4%EC%BB%A4%ED%86%A4/sentiword.ipynb#ch0000005?line=1'>2</a> from transformers import AutoTokenizer, AutoModelForSequenceClassification
#       <a href='vscode-notebook-cell:/Users/ijunhui/Downloads/ubion/%ED%95%B4%EC%BB%A4%ED%86%A4/sentiword.ipynb#ch0000005?line=3'>4</a> tokenizer = AutoTokenizer.from_pretrained("snunlp/KR-FinBert-SC")
# ...

# %%
a
# Out:
#                   전체날짜  종목명                        제목  \
# 0     2022.06.01 05:23  카카오  이시간에 카카오메인이 조선이 싹쓸이하네...
# 1     2022.06.01 08:44  카카오                돈은 많이 받으면서
# 2     2022.06.01 08:59  카카오      유영두 할아버지 넘 실망이에요~~^^
# 3     2022.06.01 09:29  카카오            빡빡이 하는짓 보면 모르나
# 4     2022.06.01 09:37  카카오     한오백년 전쟁하자는 미필 양키괴뢰!!!
# ...                ...  ...                       ...
# 6615  2022.06.30 23:31  카카오       이거보고 윤석열이 왕따라고 생각하면
# 6616  2022.06.30 23:34  카카오                    잠이 안온다
# 6617  2022.06.30 23:40  카카오           이거 액분전에 평균얼마엿어요
# 6618  2022.06.30 23:52  카카오                    나스닥 7천
# 6619  2022.06.30 23:54  카카오                   카카오 계열사
#
#                                                      본문  \
# 0     메인 7개 뉴스중에 5개가 조선1개가 동아 1개가 듣보잡 인터넷언론....이러니 주...
# 1     근무시간에 오디오라인 열어놓는게 불만이라니\n그냥 집에서 누워서 tv보면서 근무하고...
# 2     토른방에 남겨진 유영두 할아버지에 대한 댓글 입니다.\n"범수 똘마니 의심 "\n"...
# 3     김범수가 일궈낸 자리 편하게 앉아서 메타버스 빌미로 날로 먹을려고 하는거지\n\n카...
# ...
